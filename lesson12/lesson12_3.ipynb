# %%
from dotenv import load_dotenv
import os
import requests
load_dotenv()
def get_aqi_str(aqi_key:str)->str:
    url = f'https://data.moenv.gov.tw/api/v2/aqx_p_488?api_key={aqi_key}&limit=1000&sort=datacreationdate desc&format=JSON'
    try:
        r = requests.get(url)
        r.raise_for_status()
    except Exception as e:
        print(f"發生錯誤:{e}")
    return r.text

aqi_data:str = get_aqi_str(aqi_key=os.environ['AQI_KEY'])

# %%
from pydantic import BaseModel,Field

class Record(BaseModel):
    站點: str = Field(alias='sitename')
    縣市: str = Field(alias='county')
    aqi: int
    狀態: str = Field(alias='status')
    pm25: float = Field(alias='pm2.5')
    緯度: float = Field(alias='latitude')
    經度: float = Field(alias='longitude')


class AQI(BaseModel):
    records: list[Record]

aqi = AQI.model_validate_json(aqi_data)

#驗証錯誤,pm2.5和aqi有空字串,無法轉換為float
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[2], line 16
#      13 class AQI(BaseModel):
#      14     records: list[Record]
# ---> 16 aqi = AQI.model_validate_json(aqi_data)
#
# File /opt/miniconda3/envs/tvdi/lib/python3.11/site-packages/pydantic/main.py:597, in BaseModel.model_validate_json(cls, json_data, strict, context)
#     595 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     596 __tracebackhide__ = True
# --> 597 return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
#
# ValidationError: 36 validation errors for AQI
# records.15.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.41.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.100.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.126.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.174.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.178.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.201.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.214.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.229.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.231.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.240.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.244.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.258.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.262.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.285.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.298.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.313.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.315.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.324.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.328.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.341.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.356.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.361.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.382.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.386.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.400.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.425.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.440.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.466.aqi
#   Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/int_parsing
# records.466.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.470.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.484.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.529.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.613.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.697.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# records.781.`pm2.5`
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing

# %%
from pydantic import BaseModel,Field,field_validator,field_serializer

class Record(BaseModel):
    站點: str = Field(alias='sitename')
    縣市: str = Field(alias='county')
    aqi: float | None 
    狀態: str = Field(alias='status')
    pm25: float | None = Field(alias='pm2.5')
    緯度: float = Field(alias='latitude')
    經度: float = Field(alias='longitude')

    @field_validator("pm25","aqi",mode='before')
    @classmethod
    def pm25_for_empty_string(cls,v:str)->float:
        if v == '':
            return None
        else:
            return float(v)
    
    @field_serializer('緯度','經度')
    def four_digits(self,value:float)->float:
        return round(value,ndigits=4)


class AQI(BaseModel):
    records: list[Record]

aqi = AQI.model_validate_json(aqi_data)

# %%
aqi.model_dump()['records']
# Out:
# [{'站點': '屏東(枋山)',
#   '縣市': '屏東縣',
#   'aqi': 56.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 22.2609,
#   '經度': 120.6515},
#  {'站點': '花蓮（美崙）',
#   '縣市': '花蓮縣',
#   'aqi': 25.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 23.9771,
#   '經度': 121.6158},
#  {'站點': '新北(樹林)',
#   '縣市': '新北市',
#   'aqi': 30.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 24.949,
#   '經度': 121.3835},
#  {'站點': '屏東（琉球）',
#   '縣市': '屏東縣',
#   'aqi': 86.0,
#   '狀態': '普通',
#   'pm25': 34.0,
#   '緯度': 22.3522,
#   '經度': 120.3772},
#  {'站點': '臺南（麻豆）',
#   '縣市': '臺南市',
#   'aqi': 54.0,
#   '狀態': '普通',
#   'pm25': 9.0,
#   '緯度': 23.179,
#   '經度': 120.2458},
#  {'站點': '高雄（湖內）',
#   '縣市': '高雄市',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 15.0,
#   '緯度': 22.8799,
#   '經度': 120.2454},
#  {'站點': '彰化（員林）',
#   '縣市': '彰化縣',
#   'aqi': 72.0,
#   '狀態': '普通',
#   'pm25': 19.0,
#   '緯度': 23.9612,
#   '經度': 120.5637},
#  {'站點': '大城',
#   '縣市': '彰化縣',
#   'aqi': 36.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 23.8549,
#   '經度': 120.2696},
#  {'站點': '富貴角',
#   '縣市': '新北市',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 25.2968,
#   '經度': 121.5366},
#  {'站點': '麥寮',
#   '縣市': '雲林縣',
#   'aqi': 46.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 23.7535,
#   '經度': 120.2518},
#  {'站點': '關山',
#   '縣市': '臺東縣',
#   'aqi': 24.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 23.0451,
#   '經度': 121.1619},
#  {'站點': '馬公',
#   '縣市': '澎湖縣',
#   'aqi': 39.0,
#   '狀態': '良好',
#   'pm25': 14.0,
#   '緯度': 23.569,
#   '經度': 119.5662},
#  {'站點': '金門',
#   '縣市': '金門縣',
#   'aqi': 30.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 24.4321,
#   '經度': 118.3123},
#  {'站點': '馬祖',
#   '縣市': '連江縣',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 26.1537,
#   '經度': 119.9527},
#  {'站點': '埔里',
#   '縣市': '南投縣',
#   'aqi': 62.0,
#   '狀態': '普通',
#   'pm25': 20.0,
#   '緯度': 23.9688,
#   '經度': 120.9679},
#  {'站點': '復興',
#   '縣市': '高雄市',
#   'aqi': 69.0,
#   '狀態': '普通',
#   'pm25': None,
#   '緯度': 22.6087,
#   '經度': 120.312},
#  {'站點': '永和',
#   '縣市': '新北市',
#   'aqi': 26.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 25.017,
#   '經度': 121.5163},
#  {'站點': '竹山',
#   '縣市': '南投縣',
#   'aqi': 71.0,
#   '狀態': '普通',
#   'pm25': 21.0,
#   '緯度': 23.7564,
#   '經度': 120.6773},
#  {'站點': '中壢',
#   '縣市': '桃園市',
#   'aqi': 58.0,
#   '狀態': '普通',
#   'pm25': 29.0,
#   '緯度': 24.9533,
#   '經度': 121.2217},
#  {'站點': '三重',
#   '縣市': '新北市',
#   'aqi': 52.0,
#   '狀態': '普通',
#   'pm25': 10.0,
#   '緯度': 25.0726,
#   '經度': 121.4938},
#  {'站點': '冬山',
#   '縣市': '宜蘭縣',
#   'aqi': 22.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 24.6322,
#   '經度': 121.7929},
#  {'站點': '宜蘭',
#   '縣市': '宜蘭縣',
#   'aqi': 25.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 24.7479,
#   '經度': 121.7464},
#  {'站點': '陽明',
#   '縣市': '臺北市',
#   'aqi': 36.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 25.1827,
#   '經度': 121.5296},
#  {'站點': '花蓮',
#   '縣市': '花蓮縣',
#   'aqi': 25.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 23.9713,
#   '經度': 121.5998},
#  {'站點': '臺東',
#   '縣市': '臺東縣',
#   'aqi': 26.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 22.7554,
#   '經度': 121.1505},
#  {'站點': '恆春',
#   '縣市': '屏東縣',
#   'aqi': 39.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 21.9581,
#   '經度': 120.7889},
#  {'站點': '潮州',
#   '縣市': '屏東縣',
#   'aqi': 70.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 22.5231,
#   '經度': 120.5612},
#  {'站點': '屏東',
#   '縣市': '屏東縣',
#   'aqi': 74.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 22.6731,
#   '經度': 120.488},
#  {'站點': '小港',
#   '縣市': '高雄市',
#   'aqi': 65.0,
#   '狀態': '普通',
#   'pm25': 17.0,
#   '緯度': 22.5658,
#   '經度': 120.3377},
#  {'站點': '前鎮',
#   '縣市': '高雄市',
#   'aqi': 66.0,
#   '狀態': '普通',
#   'pm25': 13.0,
#   '緯度': 22.6045,
#   '經度': 120.3083},
#  {'站點': '前金',
#   '縣市': '高雄市',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 21.0,
#   '緯度': 22.6339,
#   '經度': 120.2868},
#  {'站點': '左營',
#   '縣市': '高雄市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 19.0,
#   '緯度': 22.6749,
#   '經度': 120.2929},
#  {'站點': '楠梓',
#   '縣市': '高雄市',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 17.0,
#   '緯度': 22.7337,
#   '經度': 120.3283},
#  {'站點': '林園',
#   '縣市': '高雄市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 19.0,
#   '緯度': 22.4795,
#   '經度': 120.4117},
#  {'站點': '大寮',
#   '縣市': '高雄市',
#   'aqi': 70.0,
#   '狀態': '普通',
#   'pm25': 19.0,
#   '緯度': 22.5641,
#   '經度': 120.4253},
#  {'站點': '鳳山',
#   '縣市': '高雄市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 22.6281,
#   '經度': 120.3574},
#  {'站點': '仁武',
#   '縣市': '高雄市',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 18.0,
#   '緯度': 22.6891,
#   '經度': 120.3326},
#  {'站點': '橋頭',
#   '縣市': '高雄市',
#   'aqi': 81.0,
#   '狀態': '普通',
#   'pm25': 20.0,
#   '緯度': 22.7575,
#   '經度': 120.3057},
#  {'站點': '美濃',
#   '縣市': '高雄市',
#   'aqi': 57.0,
#   '狀態': '普通',
#   'pm25': 17.0,
#   '緯度': 22.8836,
#   '經度': 120.5305},
#  {'站點': '臺南',
#   '縣市': '臺南市',
#   'aqi': 67.0,
#   '狀態': '普通',
#   'pm25': 15.0,
#   '緯度': 22.9893,
#   '經度': 120.2195},
#  {'站點': '安南',
#   '縣市': '臺南市',
#   'aqi': 67.0,
#   '狀態': '普通',
#   'pm25': 17.0,
#   '緯度': 23.0482,
#   '經度': 120.2175},
#  {'站點': '善化',
#   '縣市': '臺南市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': None,
#   '緯度': 23.1134,
#   '經度': 120.2974},
#  {'站點': '新營',
#   '縣市': '臺南市',
#   'aqi': 68.0,
#   '狀態': '普通',
#   'pm25': 19.0,
#   '緯度': 23.3056,
#   '經度': 120.3173},
#  {'站點': '嘉義',
#   '縣市': '嘉義市',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 23.4648,
#   '經度': 120.4413},
#  {'站點': '臺西',
#   '縣市': '雲林縣',
#   'aqi': 39.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 23.7022,
#   '經度': 120.1993},
#  {'站點': '朴子',
#   '縣市': '嘉義縣',
#   'aqi': 37.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 23.4654,
#   '經度': 120.2478},
#  {'站點': '新港',
#   '縣市': '嘉義縣',
#   'aqi': 62.0,
#   '狀態': '普通',
#   'pm25': 7.0,
#   '緯度': 23.5548,
#   '經度': 120.3455},
#  {'站點': '崙背',
#   '縣市': '雲林縣',
#   'aqi': 63.0,
#   '狀態': '普通',
#   'pm25': 16.0,
#   '緯度': 23.7575,
#   '經度': 120.3487},
#  {'站點': '斗六',
#   '縣市': '雲林縣',
#   'aqi': 84.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 23.7119,
#   '經度': 120.545},
#  {'站點': '南投',
#   '縣市': '南投縣',
#   'aqi': 71.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 23.913,
#   '經度': 120.6853},
#  {'站點': '二林',
#   '縣市': '彰化縣',
#   'aqi': 67.0,
#   '狀態': '普通',
#   'pm25': 13.0,
#   '緯度': 23.9252,
#   '經度': 120.4097},
#  {'站點': '線西',
#   '縣市': '彰化縣',
#   'aqi': 72.0,
#   '狀態': '普通',
#   'pm25': 16.0,
#   '緯度': 24.1317,
#   '經度': 120.4691},
#  {'站點': '彰化',
#   '縣市': '彰化縣',
#   'aqi': 81.0,
#   '狀態': '普通',
#   'pm25': 32.0,
#   '緯度': 24.066,
#   '經度': 120.5415},
#  {'站點': '西屯',
#   '縣市': '臺中市',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 34.0,
#   '緯度': 24.1622,
#   '經度': 120.6169},
#  {'站點': '忠明',
#   '縣市': '臺中市',
#   'aqi': 67.0,
#   '狀態': '普通',
#   'pm25': 26.0,
#   '緯度': 24.152,
#   '經度': 120.6411},
#  {'站點': '大里',
#   '縣市': '臺中市',
#   'aqi': 77.0,
#   '狀態': '普通',
#   'pm25': 33.0,
#   '緯度': 24.0996,
#   '經度': 120.6784},
#  {'站點': '沙鹿',
#   '縣市': '臺中市',
#   'aqi': 83.0,
#   '狀態': '普通',
#   'pm25': 33.0,
#   '緯度': 24.2256,
#   '經度': 120.5688},
#  {'站點': '豐原',
#   '縣市': '臺中市',
#   'aqi': 70.0,
#   '狀態': '普通',
#   'pm25': 26.0,
#   '緯度': 24.257,
#   '經度': 120.7425},
#  {'站點': '三義',
#   '縣市': '苗栗縣',
#   'aqi': 65.0,
#   '狀態': '普通',
#   'pm25': 31.0,
#   '緯度': 24.3825,
#   '經度': 120.7596},
#  {'站點': '苗栗',
#   '縣市': '苗栗縣',
#   'aqi': 59.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 24.565,
#   '經度': 120.8201},
#  {'站點': '頭份',
#   '縣市': '苗栗縣',
#   'aqi': 48.0,
#   '狀態': '良好',
#   'pm25': 18.0,
#   '緯度': 24.6969,
#   '經度': 120.8987},
#  {'站點': '新竹',
#   '縣市': '新竹市',
#   'aqi': 44.0,
#   '狀態': '良好',
#   'pm25': 20.0,
#   '緯度': 24.8056,
#   '經度': 120.9724},
#  {'站點': '竹東',
#   '縣市': '新竹縣',
#   'aqi': 35.0,
#   '狀態': '良好',
#   'pm25': 24.0,
#   '緯度': 24.7409,
#   '經度': 121.089},
#  {'站點': '湖口',
#   '縣市': '新竹縣',
#   'aqi': 53.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 24.9001,
#   '經度': 121.0389},
#  {'站點': '龍潭',
#   '縣市': '桃園市',
#   'aqi': 42.0,
#   '狀態': '良好',
#   'pm25': 26.0,
#   '緯度': 24.864,
#   '經度': 121.2165},
#  {'站點': '平鎮',
#   '縣市': '桃園市',
#   'aqi': 44.0,
#   '狀態': '良好',
#   'pm25': 25.0,
#   '緯度': 24.9528,
#   '經度': 121.204},
#  {'站點': '觀音',
#   '縣市': '桃園市',
#   'aqi': 50.0,
#   '狀態': '良好',
#   'pm25': 16.0,
#   '緯度': 25.0356,
#   '經度': 121.0828},
#  {'站點': '大園',
#   '縣市': '桃園市',
#   'aqi': 35.0,
#   '狀態': '良好',
#   'pm25': 13.0,
#   '緯度': 25.061,
#   '經度': 121.2025},
#  {'站點': '桃園',
#   '縣市': '桃園市',
#   'aqi': 32.0,
#   '狀態': '良好',
#   'pm25': 13.0,
#   '緯度': 24.9947,
#   '經度': 121.305},
#  {'站點': '大同',
#   '縣市': '臺北市',
#   'aqi': 51.0,
#   '狀態': '普通',
#   'pm25': 11.0,
#   '緯度': 25.0633,
#   '經度': 121.5134},
#  {'站點': '松山',
#   '縣市': '臺北市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 25.05,
#   '經度': 121.5786},
#  {'站點': '古亭',
#   '縣市': '臺北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 25.0206,
#   '經度': 121.5296},
#  {'站點': '萬華',
#   '縣市': '臺北市',
#   'aqi': 26.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 25.0465,
#   '經度': 121.508},
#  {'站點': '中山',
#   '縣市': '臺北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 25.0624,
#   '經度': 121.5265},
#  {'站點': '士林',
#   '縣市': '臺北市',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 1.0,
#   '緯度': 25.1033,
#   '經度': 121.5167},
#  {'站點': '淡水',
#   '縣市': '新北市',
#   'aqi': 35.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 25.1645,
#   '經度': 121.4492},
#  {'站點': '林口',
#   '縣市': '新北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 3.0,
#   '緯度': 25.078,
#   '經度': 121.3655},
#  {'站點': '菜寮',
#   '縣市': '新北市',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 25.069,
#   '經度': 121.481},
#  {'站點': '新莊',
#   '縣市': '新北市',
#   'aqi': 32.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 25.038,
#   '經度': 121.4325},
#  {'站點': '板橋',
#   '縣市': '新北市',
#   'aqi': 34.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 25.013,
#   '經度': 121.4587},
#  {'站點': '土城',
#   '縣市': '新北市',
#   'aqi': 30.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 24.9825,
#   '經度': 121.4519},
#  {'站點': '新店',
#   '縣市': '新北市',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 24.9772,
#   '經度': 121.5378},
#  {'站點': '萬里',
#   '縣市': '新北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 25.1797,
#   '經度': 121.6899},
#  {'站點': '汐止',
#   '縣市': '新北市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 25.0662,
#   '經度': 121.6408},
#  {'站點': '基隆',
#   '縣市': '基隆市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 25.1292,
#   '經度': 121.7601},
#  {'站點': '屏東(枋山)',
#   '縣市': '屏東縣',
#   'aqi': 56.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 22.2609,
#   '經度': 120.6515},
#  {'站點': '花蓮（美崙）',
#   '縣市': '花蓮縣',
#   'aqi': 25.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 23.9771,
#   '經度': 121.6158},
#  {'站點': '新北(樹林)',
#   '縣市': '新北市',
#   'aqi': 30.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 24.949,
#   '經度': 121.3835},
#  {'站點': '屏東（琉球）',
#   '縣市': '屏東縣',
#   'aqi': 86.0,
#   '狀態': '普通',
#   'pm25': 34.0,
#   '緯度': 22.3522,
#   '經度': 120.3772},
#  {'站點': '臺南（麻豆）',
#   '縣市': '臺南市',
#   'aqi': 54.0,
#   '狀態': '普通',
#   'pm25': 9.0,
#   '緯度': 23.179,
#   '經度': 120.2458},
#  {'站點': '高雄（湖內）',
#   '縣市': '高雄市',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 15.0,
#   '緯度': 22.8799,
#   '經度': 120.2454},
#  {'站點': '彰化（員林）',
#   '縣市': '彰化縣',
#   'aqi': 72.0,
#   '狀態': '普通',
#   'pm25': 19.0,
#   '緯度': 23.9612,
#   '經度': 120.5637},
#  {'站點': '大城',
#   '縣市': '彰化縣',
#   'aqi': 36.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 23.8549,
#   '經度': 120.2696},
#  {'站點': '富貴角',
#   '縣市': '新北市',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 25.2968,
#   '經度': 121.5366},
#  {'站點': '麥寮',
#   '縣市': '雲林縣',
#   'aqi': 46.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 23.7535,
#   '經度': 120.2518},
#  {'站點': '關山',
#   '縣市': '臺東縣',
#   'aqi': 24.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 23.0451,
#   '經度': 121.1619},
#  {'站點': '馬公',
#   '縣市': '澎湖縣',
#   'aqi': 39.0,
#   '狀態': '良好',
#   'pm25': 14.0,
#   '緯度': 23.569,
#   '經度': 119.5662},
#  {'站點': '金門',
#   '縣市': '金門縣',
#   'aqi': 30.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 24.4321,
#   '經度': 118.3123},
#  {'站點': '馬祖',
#   '縣市': '連江縣',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 26.1537,
#   '經度': 119.9527},
#  {'站點': '埔里',
#   '縣市': '南投縣',
#   'aqi': 62.0,
#   '狀態': '普通',
#   'pm25': 20.0,
#   '緯度': 23.9688,
#   '經度': 120.9679},
#  {'站點': '復興',
#   '縣市': '高雄市',
#   'aqi': 69.0,
#   '狀態': '普通',
#   'pm25': None,
#   '緯度': 22.6087,
#   '經度': 120.312},
#  {'站點': '永和',
#   '縣市': '新北市',
#   'aqi': 26.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 25.017,
#   '經度': 121.5163},
#  {'站點': '竹山',
#   '縣市': '南投縣',
#   'aqi': 71.0,
#   '狀態': '普通',
#   'pm25': 21.0,
#   '緯度': 23.7564,
#   '經度': 120.6773},
#  {'站點': '中壢',
#   '縣市': '桃園市',
#   'aqi': 58.0,
#   '狀態': '普通',
#   'pm25': 29.0,
#   '緯度': 24.9533,
#   '經度': 121.2217},
#  {'站點': '三重',
#   '縣市': '新北市',
#   'aqi': 52.0,
#   '狀態': '普通',
#   'pm25': 10.0,
#   '緯度': 25.0726,
#   '經度': 121.4938},
#  {'站點': '冬山',
#   '縣市': '宜蘭縣',
#   'aqi': 22.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 24.6322,
#   '經度': 121.7929},
#  {'站點': '宜蘭',
#   '縣市': '宜蘭縣',
#   'aqi': 25.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 24.7479,
#   '經度': 121.7464},
#  {'站點': '陽明',
#   '縣市': '臺北市',
#   'aqi': 36.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 25.1827,
#   '經度': 121.5296},
#  {'站點': '花蓮',
#   '縣市': '花蓮縣',
#   'aqi': 25.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 23.9713,
#   '經度': 121.5998},
#  {'站點': '臺東',
#   '縣市': '臺東縣',
#   'aqi': 26.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 22.7554,
#   '經度': 121.1505},
#  {'站點': '恆春',
#   '縣市': '屏東縣',
#   'aqi': 39.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 21.9581,
#   '經度': 120.7889},
#  {'站點': '潮州',
#   '縣市': '屏東縣',
#   'aqi': 70.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 22.5231,
#   '經度': 120.5612},
#  {'站點': '屏東',
#   '縣市': '屏東縣',
#   'aqi': 74.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 22.6731,
#   '經度': 120.488},
#  {'站點': '小港',
#   '縣市': '高雄市',
#   'aqi': 65.0,
#   '狀態': '普通',
#   'pm25': 17.0,
#   '緯度': 22.5658,
#   '經度': 120.3377},
#  {'站點': '前鎮',
#   '縣市': '高雄市',
#   'aqi': 66.0,
#   '狀態': '普通',
#   'pm25': 13.0,
#   '緯度': 22.6045,
#   '經度': 120.3083},
#  {'站點': '前金',
#   '縣市': '高雄市',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 21.0,
#   '緯度': 22.6339,
#   '經度': 120.2868},
#  {'站點': '左營',
#   '縣市': '高雄市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 19.0,
#   '緯度': 22.6749,
#   '經度': 120.2929},
#  {'站點': '楠梓',
#   '縣市': '高雄市',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 17.0,
#   '緯度': 22.7337,
#   '經度': 120.3283},
#  {'站點': '林園',
#   '縣市': '高雄市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 19.0,
#   '緯度': 22.4795,
#   '經度': 120.4117},
#  {'站點': '大寮',
#   '縣市': '高雄市',
#   'aqi': 70.0,
#   '狀態': '普通',
#   'pm25': 19.0,
#   '緯度': 22.5641,
#   '經度': 120.4253},
#  {'站點': '鳳山',
#   '縣市': '高雄市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 22.6281,
#   '經度': 120.3574},
#  {'站點': '仁武',
#   '縣市': '高雄市',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 18.0,
#   '緯度': 22.6891,
#   '經度': 120.3326},
#  {'站點': '橋頭',
#   '縣市': '高雄市',
#   'aqi': 81.0,
#   '狀態': '普通',
#   'pm25': 20.0,
#   '緯度': 22.7575,
#   '經度': 120.3057},
#  {'站點': '美濃',
#   '縣市': '高雄市',
#   'aqi': 57.0,
#   '狀態': '普通',
#   'pm25': 17.0,
#   '緯度': 22.8836,
#   '經度': 120.5305},
#  {'站點': '臺南',
#   '縣市': '臺南市',
#   'aqi': 67.0,
#   '狀態': '普通',
#   'pm25': 15.0,
#   '緯度': 22.9893,
#   '經度': 120.2195},
#  {'站點': '安南',
#   '縣市': '臺南市',
#   'aqi': 67.0,
#   '狀態': '普通',
#   'pm25': 17.0,
#   '緯度': 23.0482,
#   '經度': 120.2175},
#  {'站點': '善化',
#   '縣市': '臺南市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': None,
#   '緯度': 23.1134,
#   '經度': 120.2974},
#  {'站點': '新營',
#   '縣市': '臺南市',
#   'aqi': 68.0,
#   '狀態': '普通',
#   'pm25': 19.0,
#   '緯度': 23.3056,
#   '經度': 120.3173},
#  {'站點': '嘉義',
#   '縣市': '嘉義市',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 23.4648,
#   '經度': 120.4413},
#  {'站點': '臺西',
#   '縣市': '雲林縣',
#   'aqi': 39.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 23.7022,
#   '經度': 120.1993},
#  {'站點': '朴子',
#   '縣市': '嘉義縣',
#   'aqi': 37.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 23.4654,
#   '經度': 120.2478},
#  {'站點': '新港',
#   '縣市': '嘉義縣',
#   'aqi': 62.0,
#   '狀態': '普通',
#   'pm25': 7.0,
#   '緯度': 23.5548,
#   '經度': 120.3455},
#  {'站點': '崙背',
#   '縣市': '雲林縣',
#   'aqi': 63.0,
#   '狀態': '普通',
#   'pm25': 16.0,
#   '緯度': 23.7575,
#   '經度': 120.3487},
#  {'站點': '斗六',
#   '縣市': '雲林縣',
#   'aqi': 84.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 23.7119,
#   '經度': 120.545},
#  {'站點': '南投',
#   '縣市': '南投縣',
#   'aqi': 71.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 23.913,
#   '經度': 120.6853},
#  {'站點': '二林',
#   '縣市': '彰化縣',
#   'aqi': 67.0,
#   '狀態': '普通',
#   'pm25': 13.0,
#   '緯度': 23.9252,
#   '經度': 120.4097},
#  {'站點': '線西',
#   '縣市': '彰化縣',
#   'aqi': 72.0,
#   '狀態': '普通',
#   'pm25': 16.0,
#   '緯度': 24.1317,
#   '經度': 120.4691},
#  {'站點': '彰化',
#   '縣市': '彰化縣',
#   'aqi': 81.0,
#   '狀態': '普通',
#   'pm25': 32.0,
#   '緯度': 24.066,
#   '經度': 120.5415},
#  {'站點': '西屯',
#   '縣市': '臺中市',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 34.0,
#   '緯度': 24.1622,
#   '經度': 120.6169},
#  {'站點': '忠明',
#   '縣市': '臺中市',
#   'aqi': 67.0,
#   '狀態': '普通',
#   'pm25': 26.0,
#   '緯度': 24.152,
#   '經度': 120.6411},
#  {'站點': '大里',
#   '縣市': '臺中市',
#   'aqi': 77.0,
#   '狀態': '普通',
#   'pm25': 33.0,
#   '緯度': 24.0996,
#   '經度': 120.6784},
#  {'站點': '沙鹿',
#   '縣市': '臺中市',
#   'aqi': 83.0,
#   '狀態': '普通',
#   'pm25': 33.0,
#   '緯度': 24.2256,
#   '經度': 120.5688},
#  {'站點': '豐原',
#   '縣市': '臺中市',
#   'aqi': 70.0,
#   '狀態': '普通',
#   'pm25': 26.0,
#   '緯度': 24.257,
#   '經度': 120.7425},
#  {'站點': '三義',
#   '縣市': '苗栗縣',
#   'aqi': 65.0,
#   '狀態': '普通',
#   'pm25': 31.0,
#   '緯度': 24.3825,
#   '經度': 120.7596},
#  {'站點': '苗栗',
#   '縣市': '苗栗縣',
#   'aqi': 59.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 24.565,
#   '經度': 120.8201},
#  {'站點': '頭份',
#   '縣市': '苗栗縣',
#   'aqi': 48.0,
#   '狀態': '良好',
#   'pm25': 18.0,
#   '緯度': 24.6969,
#   '經度': 120.8987},
#  {'站點': '新竹',
#   '縣市': '新竹市',
#   'aqi': 44.0,
#   '狀態': '良好',
#   'pm25': 20.0,
#   '緯度': 24.8056,
#   '經度': 120.9724},
#  {'站點': '竹東',
#   '縣市': '新竹縣',
#   'aqi': 35.0,
#   '狀態': '良好',
#   'pm25': 24.0,
#   '緯度': 24.7409,
#   '經度': 121.089},
#  {'站點': '湖口',
#   '縣市': '新竹縣',
#   'aqi': 53.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 24.9001,
#   '經度': 121.0389},
#  {'站點': '龍潭',
#   '縣市': '桃園市',
#   'aqi': 42.0,
#   '狀態': '良好',
#   'pm25': 26.0,
#   '緯度': 24.864,
#   '經度': 121.2165},
#  {'站點': '平鎮',
#   '縣市': '桃園市',
#   'aqi': 44.0,
#   '狀態': '良好',
#   'pm25': 25.0,
#   '緯度': 24.9528,
#   '經度': 121.204},
#  {'站點': '觀音',
#   '縣市': '桃園市',
#   'aqi': 50.0,
#   '狀態': '良好',
#   'pm25': 16.0,
#   '緯度': 25.0356,
#   '經度': 121.0828},
#  {'站點': '大園',
#   '縣市': '桃園市',
#   'aqi': 35.0,
#   '狀態': '良好',
#   'pm25': 13.0,
#   '緯度': 25.061,
#   '經度': 121.2025},
#  {'站點': '桃園',
#   '縣市': '桃園市',
#   'aqi': 32.0,
#   '狀態': '良好',
#   'pm25': 13.0,
#   '緯度': 24.9947,
#   '經度': 121.305},
#  {'站點': '大同',
#   '縣市': '臺北市',
#   'aqi': 51.0,
#   '狀態': '普通',
#   'pm25': 11.0,
#   '緯度': 25.0633,
#   '經度': 121.5134},
#  {'站點': '松山',
#   '縣市': '臺北市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 25.05,
#   '經度': 121.5786},
#  {'站點': '古亭',
#   '縣市': '臺北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 25.0206,
#   '經度': 121.5296},
#  {'站點': '萬華',
#   '縣市': '臺北市',
#   'aqi': 26.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 25.0465,
#   '經度': 121.508},
#  {'站點': '中山',
#   '縣市': '臺北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 25.0624,
#   '經度': 121.5265},
#  {'站點': '士林',
#   '縣市': '臺北市',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 1.0,
#   '緯度': 25.1033,
#   '經度': 121.5167},
#  {'站點': '淡水',
#   '縣市': '新北市',
#   'aqi': 35.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 25.1645,
#   '經度': 121.4492},
#  {'站點': '林口',
#   '縣市': '新北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 3.0,
#   '緯度': 25.078,
#   '經度': 121.3655},
#  {'站點': '菜寮',
#   '縣市': '新北市',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 25.069,
#   '經度': 121.481},
#  {'站點': '新莊',
#   '縣市': '新北市',
#   'aqi': 32.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 25.038,
#   '經度': 121.4325},
#  {'站點': '板橋',
#   '縣市': '新北市',
#   'aqi': 34.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 25.013,
#   '經度': 121.4587},
#  {'站點': '土城',
#   '縣市': '新北市',
#   'aqi': 30.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 24.9825,
#   '經度': 121.4519},
#  {'站點': '新店',
#   '縣市': '新北市',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 24.9772,
#   '經度': 121.5378},
#  {'站點': '萬里',
#   '縣市': '新北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 25.1797,
#   '經度': 121.6899},
#  {'站點': '汐止',
#   '縣市': '新北市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 25.0662,
#   '經度': 121.6408},
#  {'站點': '基隆',
#   '縣市': '基隆市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 25.1292,
#   '經度': 121.7601},
#  {'站點': '屏東(枋山)',
#   '縣市': '屏東縣',
#   'aqi': 52.0,
#   '狀態': '普通',
#   'pm25': 19.0,
#   '緯度': 22.2609,
#   '經度': 120.6515},
#  {'站點': '花蓮（美崙）',
#   '縣市': '花蓮縣',
#   'aqi': 25.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 23.9771,
#   '經度': 121.6158},
#  {'站點': '新北(樹林)',
#   '縣市': '新北市',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 24.949,
#   '經度': 121.3835},
#  {'站點': '屏東（琉球）',
#   '縣市': '屏東縣',
#   'aqi': 83.0,
#   '狀態': '普通',
#   'pm25': 37.0,
#   '緯度': 22.3522,
#   '經度': 120.3772},
#  {'站點': '臺南（麻豆）',
#   '縣市': '臺南市',
#   'aqi': 61.0,
#   '狀態': '普通',
#   'pm25': None,
#   '緯度': 23.179,
#   '經度': 120.2458},
#  {'站點': '高雄（湖內）',
#   '縣市': '高雄市',
#   'aqi': 80.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 22.8799,
#   '經度': 120.2454},
#  {'站點': '彰化（員林）',
#   '縣市': '彰化縣',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 23.9612,
#   '經度': 120.5637},
#  {'站點': '大城',
#   '縣市': '彰化縣',
#   'aqi': 36.0,
#   '狀態': '良好',
#   'pm25': 14.0,
#   '緯度': 23.8549,
#   '經度': 120.2696},
#  {'站點': '富貴角',
#   '縣市': '新北市',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': None,
#   '緯度': 25.2968,
#   '經度': 121.5366},
#  {'站點': '麥寮',
#   '縣市': '雲林縣',
#   'aqi': 48.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 23.7535,
#   '經度': 120.2518},
#  {'站點': '關山',
#   '縣市': '臺東縣',
#   'aqi': 22.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 23.0451,
#   '經度': 121.1619},
#  {'站點': '馬公',
#   '縣市': '澎湖縣',
#   'aqi': 38.0,
#   '狀態': '良好',
#   'pm25': 3.0,
#   '緯度': 23.569,
#   '經度': 119.5662},
#  {'站點': '金門',
#   '縣市': '金門縣',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 16.0,
#   '緯度': 24.4321,
#   '經度': 118.3123},
#  {'站點': '馬祖',
#   '縣市': '連江縣',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 26.1537,
#   '經度': 119.9527},
#  {'站點': '埔里',
#   '縣市': '南投縣',
#   'aqi': 63.0,
#   '狀態': '普通',
#   'pm25': 15.0,
#   '緯度': 23.9688,
#   '經度': 120.9679},
#  {'站點': '復興',
#   '縣市': '高雄市',
#   'aqi': 70.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 22.6087,
#   '經度': 120.312},
#  {'站點': '永和',
#   '縣市': '新北市',
#   'aqi': 27.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 25.017,
#   '經度': 121.5163},
#  {'站點': '竹山',
#   '縣市': '南投縣',
#   'aqi': 72.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 23.7564,
#   '經度': 120.6773},
#  {'站點': '中壢',
#   '縣市': '桃園市',
#   'aqi': 36.0,
#   '狀態': '良好',
#   'pm25': 20.0,
#   '緯度': 24.9533,
#   '經度': 121.2217},
#  {'站點': '三重',
#   '縣市': '新北市',
#   'aqi': 35.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 25.0726,
#   '經度': 121.4938},
#  {'站點': '冬山',
#   '縣市': '宜蘭縣',
#   'aqi': 19.0,
#   '狀態': '良好',
#   'pm25': 2.0,
#   '緯度': 24.6322,
#   '經度': 121.7929},
#  {'站點': '宜蘭',
#   '縣市': '宜蘭縣',
#   'aqi': 23.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 24.7479,
#   '經度': 121.7464},
#  {'站點': '陽明',
#   '縣市': '臺北市',
#   'aqi': 37.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 25.1827,
#   '經度': 121.5296},
#  {'站點': '花蓮',
#   '縣市': '花蓮縣',
#   'aqi': 25.0,
#   '狀態': '良好',
#   'pm25': 3.0,
#   '緯度': 23.9713,
#   '經度': 121.5998},
#  {'站點': '臺東',
#   '縣市': '臺東縣',
#   'aqi': 25.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 22.7554,
#   '經度': 121.1505},
#  {'站點': '恆春',
#   '縣市': '屏東縣',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 21.9581,
#   '經度': 120.7889},
#  {'站點': '潮州',
#   '縣市': '屏東縣',
#   'aqi': 67.0,
#   '狀態': '普通',
#   'pm25': 26.0,
#   '緯度': 22.5231,
#   '經度': 120.5612},
#  {'站點': '屏東',
#   '縣市': '屏東縣',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 22.6731,
#   '經度': 120.488},
#  {'站點': '小港',
#   '縣市': '高雄市',
#   'aqi': 69.0,
#   '狀態': '普通',
#   'pm25': 16.0,
#   '緯度': 22.5658,
#   '經度': 120.3377},
#  {'站點': '前鎮',
#   '縣市': '高雄市',
#   'aqi': 71.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 22.6045,
#   '經度': 120.3083},
#  {'站點': '前金',
#   '縣市': '高雄市',
#   'aqi': 77.0,
#   '狀態': '普通',
#   'pm25': 29.0,
#   '緯度': 22.6339,
#   '經度': 120.2868},
#  {'站點': '左營',
#   '縣市': '高雄市',
#   'aqi': 85.0,
#   '狀態': '普通',
#   'pm25': None,
#   '緯度': 22.6749,
#   '經度': 120.2929},
#  {'站點': '楠梓',
#   '縣市': '高雄市',
#   'aqi': 78.0,
#   '狀態': '普通',
#   'pm25': 37.0,
#   '緯度': 22.7337,
#   '經度': 120.3283},
#  {'站點': '林園',
#   '縣市': '高雄市',
#   'aqi': 81.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 22.4795,
#   '經度': 120.4117},
#  {'站點': '大寮',
#   '縣市': '高雄市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 18.0,
#   '緯度': 22.5641,
#   '經度': 120.4253},
#  {'站點': '鳳山',
#   '縣市': '高雄市',
#   'aqi': 78.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 22.6281,
#   '經度': 120.3574},
#  {'站點': '仁武',
#   '縣市': '高雄市',
#   'aqi': 81.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 22.6891,
#   '經度': 120.3326},
#  {'站點': '橋頭',
#   '縣市': '高雄市',
#   'aqi': 87.0,
#   '狀態': '普通',
#   'pm25': 35.0,
#   '緯度': 22.7575,
#   '經度': 120.3057},
#  {'站點': '美濃',
#   '縣市': '高雄市',
#   'aqi': 61.0,
#   '狀態': '普通',
#   'pm25': 16.0,
#   '緯度': 22.8836,
#   '經度': 120.5305},
#  {'站點': '臺南',
#   '縣市': '臺南市',
#   'aqi': 72.0,
#   '狀態': '普通',
#   'pm25': 18.0,
#   '緯度': 22.9893,
#   '經度': 120.2195},
#  {'站點': '安南',
#   '縣市': '臺南市',
#   'aqi': 74.0,
#   '狀態': '普通',
#   'pm25': 16.0,
#   '緯度': 23.0482,
#   '經度': 120.2175},
#  {'站點': '善化',
#   '縣市': '臺南市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 23.1134,
#   '經度': 120.2974},
#  {'站點': '新營',
#   '縣市': '臺南市',
#   'aqi': 71.0,
#   '狀態': '普通',
#   'pm25': 18.0,
#   '緯度': 23.3056,
#   '經度': 120.3173},
#  {'站點': '嘉義',
#   '縣市': '嘉義市',
#   'aqi': 78.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 23.4648,
#   '經度': 120.4413},
#  {'站點': '臺西',
#   '縣市': '雲林縣',
#   'aqi': 46.0,
#   '狀態': '良好',
#   'pm25': None,
#   '緯度': 23.7022,
#   '經度': 120.1993},
#  {'站點': '朴子',
#   '縣市': '嘉義縣',
#   'aqi': 38.0,
#   '狀態': '良好',
#   'pm25': 12.0,
#   '緯度': 23.4654,
#   '經度': 120.2478},
#  {'站點': '新港',
#   '縣市': '嘉義縣',
#   'aqi': 69.0,
#   '狀態': '普通',
#   'pm25': 17.0,
#   '緯度': 23.5548,
#   '經度': 120.3455},
#  {'站點': '崙背',
#   '縣市': '雲林縣',
#   'aqi': 68.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 23.7575,
#   '經度': 120.3487},
#  {'站點': '斗六',
#   '縣市': '雲林縣',
#   'aqi': 89.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 23.7119,
#   '經度': 120.545},
#  {'站點': '南投',
#   '縣市': '南投縣',
#   'aqi': 72.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 23.913,
#   '經度': 120.6853},
#  {'站點': '二林',
#   '縣市': '彰化縣',
#   'aqi': 74.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 23.9252,
#   '經度': 120.4097},
#  {'站點': '線西',
#   '縣市': '彰化縣',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 33.0,
#   '緯度': 24.1317,
#   '經度': 120.4691},
#  {'站點': '彰化',
#   '縣市': '彰化縣',
#   'aqi': 79.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 24.066,
#   '經度': 120.5415},
#  {'站點': '西屯',
#   '縣市': '臺中市',
#   'aqi': 69.0,
#   '狀態': '普通',
#   'pm25': 29.0,
#   '緯度': 24.1622,
#   '經度': 120.6169},
#  {'站點': '忠明',
#   '縣市': '臺中市',
#   'aqi': 66.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 24.152,
#   '經度': 120.6411},
#  {'站點': '大里',
#   '縣市': '臺中市',
#   'aqi': 74.0,
#   '狀態': '普通',
#   'pm25': 30.0,
#   '緯度': 24.0996,
#   '經度': 120.6784},
#  {'站點': '沙鹿',
#   '縣市': '臺中市',
#   'aqi': 80.0,
#   '狀態': '普通',
#   'pm25': 36.0,
#   '緯度': 24.2256,
#   '經度': 120.5688},
#  {'站點': '豐原',
#   '縣市': '臺中市',
#   'aqi': 68.0,
#   '狀態': '普通',
#   'pm25': 28.0,
#   '緯度': 24.257,
#   '經度': 120.7425},
#  {'站點': '三義',
#   '縣市': '苗栗縣',
#   'aqi': 58.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 24.3825,
#   '經度': 120.7596},
#  {'站點': '苗栗',
#   '縣市': '苗栗縣',
#   'aqi': 52.0,
#   '狀態': '普通',
#   'pm25': None,
#   '緯度': 24.565,
#   '經度': 120.8201},
#  {'站點': '頭份',
#   '縣市': '苗栗縣',
#   'aqi': 44.0,
#   '狀態': '良好',
#   'pm25': 16.0,
#   '緯度': 24.6969,
#   '經度': 120.8987},
#  {'站點': '新竹',
#   '縣市': '新竹市',
#   'aqi': 42.0,
#   '狀態': '良好',
#   'pm25': None,
#   '緯度': 24.8056,
#   '經度': 120.9724},
#  {'站點': '竹東',
#   '縣市': '新竹縣',
#   'aqi': 23.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 24.7409,
#   '經度': 121.089},
#  {'站點': '湖口',
#   '縣市': '新竹縣',
#   'aqi': 48.0,
#   '狀態': '良好',
#   'pm25': 28.0,
#   '緯度': 24.9001,
#   '經度': 121.0389},
#  {'站點': '龍潭',
#   '縣市': '桃園市',
#   'aqi': 35.0,
#   '狀態': '良好',
#   'pm25': 15.0,
#   '緯度': 24.864,
#   '經度': 121.2165},
#  {'站點': '平鎮',
#   '縣市': '桃園市',
#   'aqi': 35.0,
#   '狀態': '良好',
#   'pm25': 19.0,
#   '緯度': 24.9528,
#   '經度': 121.204},
#  {'站點': '觀音',
#   '縣市': '桃園市',
#   'aqi': 54.0,
#   '狀態': '普通',
#   'pm25': 13.0,
#   '緯度': 25.0356,
#   '經度': 121.0828},
#  {'站點': '大園',
#   '縣市': '桃園市',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 15.0,
#   '緯度': 25.061,
#   '經度': 121.2025},
#  {'站點': '桃園',
#   '縣市': '桃園市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 24.9947,
#   '經度': 121.305},
#  {'站點': '大同',
#   '縣市': '臺北市',
#   'aqi': 52.0,
#   '狀態': '普通',
#   'pm25': 11.0,
#   '緯度': 25.0633,
#   '經度': 121.5134},
#  {'站點': '松山',
#   '縣市': '臺北市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': None,
#   '緯度': 25.05,
#   '經度': 121.5786},
#  {'站點': '古亭',
#   '縣市': '臺北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 25.0206,
#   '經度': 121.5296},
#  {'站點': '萬華',
#   '縣市': '臺北市',
#   'aqi': 26.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 25.0465,
#   '經度': 121.508},
#  {'站點': '中山',
#   '縣市': '臺北市',
#   'aqi': 30.0,
#   '狀態': '良好',
#   'pm25': 12.0,
#   '緯度': 25.0624,
#   '經度': 121.5265},
#  {'站點': '士林',
#   '縣市': '臺北市',
#   'aqi': 34.0,
#   '狀態': '良好',
#   'pm25': None,
#   '緯度': 25.1033,
#   '經度': 121.5167},
#  {'站點': '淡水',
#   '縣市': '新北市',
#   'aqi': 35.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 25.1645,
#   '經度': 121.4492},
#  {'站點': '林口',
#   '縣市': '新北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 25.078,
#   '經度': 121.3655},
#  {'站點': '菜寮',
#   '縣市': '新北市',
#   'aqi': 32.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 25.069,
#   '經度': 121.481},
#  {'站點': '新莊',
#   '縣市': '新北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 25.038,
#   '經度': 121.4325},
#  {'站點': '板橋',
#   '縣市': '新北市',
#   'aqi': 32.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 25.013,
#   '經度': 121.4587},
#  {'站點': '土城',
#   '縣市': '新北市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 24.9825,
#   '經度': 121.4519},
#  {'站點': '新店',
#   '縣市': '新北市',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 24.9772,
#   '經度': 121.5378},
#  {'站點': '萬里',
#   '縣市': '新北市',
#   'aqi': 30.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 25.1797,
#   '經度': 121.6899},
#  {'站點': '汐止',
#   '縣市': '新北市',
#   'aqi': 27.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 25.0662,
#   '經度': 121.6408},
#  {'站點': '基隆',
#   '縣市': '基隆市',
#   'aqi': 26.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 25.1292,
#   '經度': 121.7601},
#  {'站點': '屏東(枋山)',
#   '縣市': '屏東縣',
#   'aqi': 52.0,
#   '狀態': '普通',
#   'pm25': 19.0,
#   '緯度': 22.2609,
#   '經度': 120.6515},
#  {'站點': '新北(樹林)',
#   '縣市': '新北市',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 24.949,
#   '經度': 121.3835},
#  {'站點': '屏東（琉球）',
#   '縣市': '屏東縣',
#   'aqi': 83.0,
#   '狀態': '普通',
#   'pm25': 37.0,
#   '緯度': 22.3522,
#   '經度': 120.3772},
#  {'站點': '臺南（麻豆）',
#   '縣市': '臺南市',
#   'aqi': 61.0,
#   '狀態': '普通',
#   'pm25': None,
#   '緯度': 23.179,
#   '經度': 120.2458},
#  {'站點': '高雄（湖內）',
#   '縣市': '高雄市',
#   'aqi': 80.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 22.8799,
#   '經度': 120.2454},
#  {'站點': '彰化（員林）',
#   '縣市': '彰化縣',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 23.9612,
#   '經度': 120.5637},
#  {'站點': '大城',
#   '縣市': '彰化縣',
#   'aqi': 36.0,
#   '狀態': '良好',
#   'pm25': 14.0,
#   '緯度': 23.8549,
#   '經度': 120.2696},
#  {'站點': '富貴角',
#   '縣市': '新北市',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': None,
#   '緯度': 25.2968,
#   '經度': 121.5366},
#  {'站點': '麥寮',
#   '縣市': '雲林縣',
#   'aqi': 48.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 23.7535,
#   '經度': 120.2518},
#  {'站點': '關山',
#   '縣市': '臺東縣',
#   'aqi': 22.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 23.0451,
#   '經度': 121.1619},
#  {'站點': '馬公',
#   '縣市': '澎湖縣',
#   'aqi': 38.0,
#   '狀態': '良好',
#   'pm25': 3.0,
#   '緯度': 23.569,
#   '經度': 119.5662},
#  {'站點': '金門',
#   '縣市': '金門縣',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 16.0,
#   '緯度': 24.4321,
#   '經度': 118.3123},
#  {'站點': '馬祖',
#   '縣市': '連江縣',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 26.1537,
#   '經度': 119.9527},
#  {'站點': '埔里',
#   '縣市': '南投縣',
#   'aqi': 63.0,
#   '狀態': '普通',
#   'pm25': 15.0,
#   '緯度': 23.9688,
#   '經度': 120.9679},
#  {'站點': '復興',
#   '縣市': '高雄市',
#   'aqi': 70.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 22.6087,
#   '經度': 120.312},
#  {'站點': '永和',
#   '縣市': '新北市',
#   'aqi': 27.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 25.017,
#   '經度': 121.5163},
#  {'站點': '竹山',
#   '縣市': '南投縣',
#   'aqi': 72.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 23.7564,
#   '經度': 120.6773},
#  {'站點': '中壢',
#   '縣市': '桃園市',
#   'aqi': 36.0,
#   '狀態': '良好',
#   'pm25': 20.0,
#   '緯度': 24.9533,
#   '經度': 121.2217},
#  {'站點': '三重',
#   '縣市': '新北市',
#   'aqi': 35.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 25.0726,
#   '經度': 121.4938},
#  {'站點': '冬山',
#   '縣市': '宜蘭縣',
#   'aqi': 19.0,
#   '狀態': '良好',
#   'pm25': 2.0,
#   '緯度': 24.6322,
#   '經度': 121.7929},
#  {'站點': '宜蘭',
#   '縣市': '宜蘭縣',
#   'aqi': 23.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 24.7479,
#   '經度': 121.7464},
#  {'站點': '陽明',
#   '縣市': '臺北市',
#   'aqi': 37.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 25.1827,
#   '經度': 121.5296},
#  {'站點': '花蓮',
#   '縣市': '花蓮縣',
#   'aqi': 25.0,
#   '狀態': '良好',
#   'pm25': 3.0,
#   '緯度': 23.9713,
#   '經度': 121.5998},
#  {'站點': '臺東',
#   '縣市': '臺東縣',
#   'aqi': 25.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 22.7554,
#   '經度': 121.1505},
#  {'站點': '恆春',
#   '縣市': '屏東縣',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 21.9581,
#   '經度': 120.7889},
#  {'站點': '潮州',
#   '縣市': '屏東縣',
#   'aqi': 67.0,
#   '狀態': '普通',
#   'pm25': 26.0,
#   '緯度': 22.5231,
#   '經度': 120.5612},
#  {'站點': '屏東',
#   '縣市': '屏東縣',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 22.6731,
#   '經度': 120.488},
#  {'站點': '小港',
#   '縣市': '高雄市',
#   'aqi': 69.0,
#   '狀態': '普通',
#   'pm25': 16.0,
#   '緯度': 22.5658,
#   '經度': 120.3377},
#  {'站點': '前鎮',
#   '縣市': '高雄市',
#   'aqi': 71.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 22.6045,
#   '經度': 120.3083},
#  {'站點': '前金',
#   '縣市': '高雄市',
#   'aqi': 77.0,
#   '狀態': '普通',
#   'pm25': 29.0,
#   '緯度': 22.6339,
#   '經度': 120.2868},
#  {'站點': '左營',
#   '縣市': '高雄市',
#   'aqi': 85.0,
#   '狀態': '普通',
#   'pm25': None,
#   '緯度': 22.6749,
#   '經度': 120.2929},
#  {'站點': '楠梓',
#   '縣市': '高雄市',
#   'aqi': 78.0,
#   '狀態': '普通',
#   'pm25': 37.0,
#   '緯度': 22.7337,
#   '經度': 120.3283},
#  {'站點': '林園',
#   '縣市': '高雄市',
#   'aqi': 81.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 22.4795,
#   '經度': 120.4117},
#  {'站點': '大寮',
#   '縣市': '高雄市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 18.0,
#   '緯度': 22.5641,
#   '經度': 120.4253},
#  {'站點': '鳳山',
#   '縣市': '高雄市',
#   'aqi': 78.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 22.6281,
#   '經度': 120.3574},
#  {'站點': '仁武',
#   '縣市': '高雄市',
#   'aqi': 81.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 22.6891,
#   '經度': 120.3326},
#  {'站點': '橋頭',
#   '縣市': '高雄市',
#   'aqi': 87.0,
#   '狀態': '普通',
#   'pm25': 35.0,
#   '緯度': 22.7575,
#   '經度': 120.3057},
#  {'站點': '美濃',
#   '縣市': '高雄市',
#   'aqi': 61.0,
#   '狀態': '普通',
#   'pm25': 16.0,
#   '緯度': 22.8836,
#   '經度': 120.5305},
#  {'站點': '臺南',
#   '縣市': '臺南市',
#   'aqi': 72.0,
#   '狀態': '普通',
#   'pm25': 18.0,
#   '緯度': 22.9893,
#   '經度': 120.2195},
#  {'站點': '安南',
#   '縣市': '臺南市',
#   'aqi': 74.0,
#   '狀態': '普通',
#   'pm25': 16.0,
#   '緯度': 23.0482,
#   '經度': 120.2175},
#  {'站點': '善化',
#   '縣市': '臺南市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 23.1134,
#   '經度': 120.2974},
#  {'站點': '新營',
#   '縣市': '臺南市',
#   'aqi': 71.0,
#   '狀態': '普通',
#   'pm25': 18.0,
#   '緯度': 23.3056,
#   '經度': 120.3173},
#  {'站點': '嘉義',
#   '縣市': '嘉義市',
#   'aqi': 78.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 23.4648,
#   '經度': 120.4413},
#  {'站點': '臺西',
#   '縣市': '雲林縣',
#   'aqi': 46.0,
#   '狀態': '良好',
#   'pm25': None,
#   '緯度': 23.7022,
#   '經度': 120.1993},
#  {'站點': '朴子',
#   '縣市': '嘉義縣',
#   'aqi': 38.0,
#   '狀態': '良好',
#   'pm25': 12.0,
#   '緯度': 23.4654,
#   '經度': 120.2478},
#  {'站點': '新港',
#   '縣市': '嘉義縣',
#   'aqi': 69.0,
#   '狀態': '普通',
#   'pm25': 17.0,
#   '緯度': 23.5548,
#   '經度': 120.3455},
#  {'站點': '崙背',
#   '縣市': '雲林縣',
#   'aqi': 68.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 23.7575,
#   '經度': 120.3487},
#  {'站點': '斗六',
#   '縣市': '雲林縣',
#   'aqi': 89.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 23.7119,
#   '經度': 120.545},
#  {'站點': '南投',
#   '縣市': '南投縣',
#   'aqi': 72.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 23.913,
#   '經度': 120.6853},
#  {'站點': '二林',
#   '縣市': '彰化縣',
#   'aqi': 74.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 23.9252,
#   '經度': 120.4097},
#  {'站點': '線西',
#   '縣市': '彰化縣',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 33.0,
#   '緯度': 24.1317,
#   '經度': 120.4691},
#  {'站點': '彰化',
#   '縣市': '彰化縣',
#   'aqi': 79.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 24.066,
#   '經度': 120.5415},
#  {'站點': '西屯',
#   '縣市': '臺中市',
#   'aqi': 69.0,
#   '狀態': '普通',
#   'pm25': 29.0,
#   '緯度': 24.1622,
#   '經度': 120.6169},
#  {'站點': '忠明',
#   '縣市': '臺中市',
#   'aqi': 66.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 24.152,
#   '經度': 120.6411},
#  {'站點': '大里',
#   '縣市': '臺中市',
#   'aqi': 74.0,
#   '狀態': '普通',
#   'pm25': 30.0,
#   '緯度': 24.0996,
#   '經度': 120.6784},
#  {'站點': '沙鹿',
#   '縣市': '臺中市',
#   'aqi': 80.0,
#   '狀態': '普通',
#   'pm25': 36.0,
#   '緯度': 24.2256,
#   '經度': 120.5688},
#  {'站點': '豐原',
#   '縣市': '臺中市',
#   'aqi': 68.0,
#   '狀態': '普通',
#   'pm25': 28.0,
#   '緯度': 24.257,
#   '經度': 120.7425},
#  {'站點': '三義',
#   '縣市': '苗栗縣',
#   'aqi': 58.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 24.3825,
#   '經度': 120.7596},
#  {'站點': '苗栗',
#   '縣市': '苗栗縣',
#   'aqi': 52.0,
#   '狀態': '普通',
#   'pm25': None,
#   '緯度': 24.565,
#   '經度': 120.8201},
#  {'站點': '頭份',
#   '縣市': '苗栗縣',
#   'aqi': 44.0,
#   '狀態': '良好',
#   'pm25': 16.0,
#   '緯度': 24.6969,
#   '經度': 120.8987},
#  {'站點': '新竹',
#   '縣市': '新竹市',
#   'aqi': 42.0,
#   '狀態': '良好',
#   'pm25': None,
#   '緯度': 24.8056,
#   '經度': 120.9724},
#  {'站點': '竹東',
#   '縣市': '新竹縣',
#   'aqi': 23.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 24.7409,
#   '經度': 121.089},
#  {'站點': '湖口',
#   '縣市': '新竹縣',
#   'aqi': 48.0,
#   '狀態': '良好',
#   'pm25': 28.0,
#   '緯度': 24.9001,
#   '經度': 121.0389},
#  {'站點': '龍潭',
#   '縣市': '桃園市',
#   'aqi': 35.0,
#   '狀態': '良好',
#   'pm25': 15.0,
#   '緯度': 24.864,
#   '經度': 121.2165},
#  {'站點': '平鎮',
#   '縣市': '桃園市',
#   'aqi': 35.0,
#   '狀態': '良好',
#   'pm25': 19.0,
#   '緯度': 24.9528,
#   '經度': 121.204},
#  {'站點': '觀音',
#   '縣市': '桃園市',
#   'aqi': 54.0,
#   '狀態': '普通',
#   'pm25': 13.0,
#   '緯度': 25.0356,
#   '經度': 121.0828},
#  {'站點': '大園',
#   '縣市': '桃園市',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 15.0,
#   '緯度': 25.061,
#   '經度': 121.2025},
#  {'站點': '桃園',
#   '縣市': '桃園市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 24.9947,
#   '經度': 121.305},
#  {'站點': '大同',
#   '縣市': '臺北市',
#   'aqi': 52.0,
#   '狀態': '普通',
#   'pm25': 11.0,
#   '緯度': 25.0633,
#   '經度': 121.5134},
#  {'站點': '松山',
#   '縣市': '臺北市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': None,
#   '緯度': 25.05,
#   '經度': 121.5786},
#  {'站點': '古亭',
#   '縣市': '臺北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 25.0206,
#   '經度': 121.5296},
#  {'站點': '萬華',
#   '縣市': '臺北市',
#   'aqi': 26.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 25.0465,
#   '經度': 121.508},
#  {'站點': '中山',
#   '縣市': '臺北市',
#   'aqi': 30.0,
#   '狀態': '良好',
#   'pm25': 12.0,
#   '緯度': 25.0624,
#   '經度': 121.5265},
#  {'站點': '士林',
#   '縣市': '臺北市',
#   'aqi': 34.0,
#   '狀態': '良好',
#   'pm25': None,
#   '緯度': 25.1033,
#   '經度': 121.5167},
#  {'站點': '淡水',
#   '縣市': '新北市',
#   'aqi': 35.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 25.1645,
#   '經度': 121.4492},
#  {'站點': '林口',
#   '縣市': '新北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 25.078,
#   '經度': 121.3655},
#  {'站點': '菜寮',
#   '縣市': '新北市',
#   'aqi': 32.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 25.069,
#   '經度': 121.481},
#  {'站點': '新莊',
#   '縣市': '新北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 25.038,
#   '經度': 121.4325},
#  {'站點': '板橋',
#   '縣市': '新北市',
#   'aqi': 32.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 25.013,
#   '經度': 121.4587},
#  {'站點': '土城',
#   '縣市': '新北市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 24.9825,
#   '經度': 121.4519},
#  {'站點': '新店',
#   '縣市': '新北市',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 24.9772,
#   '經度': 121.5378},
#  {'站點': '萬里',
#   '縣市': '新北市',
#   'aqi': 30.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 25.1797,
#   '經度': 121.6899},
#  {'站點': '汐止',
#   '縣市': '新北市',
#   'aqi': 27.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 25.0662,
#   '經度': 121.6408},
#  {'站點': '基隆',
#   '縣市': '基隆市',
#   'aqi': 26.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 25.1292,
#   '經度': 121.7601},
#  {'站點': '屏東(枋山)',
#   '縣市': '屏東縣',
#   'aqi': 49.0,
#   '狀態': '良好',
#   'pm25': 22.0,
#   '緯度': 22.2609,
#   '經度': 120.6515},
#  {'站點': '新北(樹林)',
#   '縣市': '新北市',
#   'aqi': 48.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 24.949,
#   '經度': 121.3835},
#  {'站點': '屏東（琉球）',
#   '縣市': '屏東縣',
#   'aqi': 79.0,
#   '狀態': '普通',
#   'pm25': None,
#   '緯度': 22.3522,
#   '經度': 120.3772},
#  {'站點': '臺南（麻豆）',
#   '縣市': '臺南市',
#   'aqi': 58.0,
#   '狀態': '普通',
#   'pm25': 16.0,
#   '緯度': 23.179,
#   '經度': 120.2458},
#  {'站點': '高雄（湖內）',
#   '縣市': '高雄市',
#   'aqi': 80.0,
#   '狀態': '普通',
#   'pm25': 31.0,
#   '緯度': 22.8799,
#   '經度': 120.2454},
#  {'站點': '彰化（員林）',
#   '縣市': '彰化縣',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 23.9612,
#   '經度': 120.5637},
#  {'站點': '大城',
#   '縣市': '彰化縣',
#   'aqi': 37.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 23.8549,
#   '經度': 120.2696},
#  {'站點': '富貴角',
#   '縣市': '新北市',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 25.2968,
#   '經度': 121.5366},
#  {'站點': '麥寮',
#   '縣市': '雲林縣',
#   'aqi': 51.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 23.7535,
#   '經度': 120.2518},
#  {'站點': '關山',
#   '縣市': '臺東縣',
#   'aqi': 20.0,
#   '狀態': '良好',
#   'pm25': 3.0,
#   '緯度': 23.0451,
#   '經度': 121.1619},
#  {'站點': '馬公',
#   '縣市': '澎湖縣',
#   'aqi': 38.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 23.569,
#   '經度': 119.5662},
#  {'站點': '金門',
#   '縣市': '金門縣',
#   'aqi': 27.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 24.4321,
#   '經度': 118.3123},
#  {'站點': '馬祖',
#   '縣市': '連江縣',
#   'aqi': 34.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 26.1537,
#   '經度': 119.9527},
#  {'站點': '埔里',
#   '縣市': '南投縣',
#   'aqi': 66.0,
#   '狀態': '普通',
#   'pm25': 15.0,
#   '緯度': 23.9688,
#   '經度': 120.9679},
#  {'站點': '復興',
#   '縣市': '高雄市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 17.0,
#   '緯度': 22.6087,
#   '經度': 120.312},
#  {'站點': '永和',
#   '縣市': '新北市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 25.017,
#   '經度': 121.5163},
#  {'站點': '竹山',
#   '縣市': '南投縣',
#   'aqi': 74.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 23.7564,
#   '經度': 120.6773},
#  {'站點': '中壢',
#   '縣市': '桃園市',
#   'aqi': 29.0,
#   '狀態': '良好',
#   'pm25': None,
#   '緯度': 24.9533,
#   '經度': 121.2217},
#  {'站點': '三重',
#   '縣市': '新北市',
#   'aqi': 50.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 25.0726,
#   '經度': 121.4938},
#  {'站點': '冬山',
#   '縣市': '宜蘭縣',
#   'aqi': 19.0,
#   '狀態': '良好',
#   'pm25': 3.0,
#   '緯度': 24.6322,
#   '經度': 121.7929},
#  {'站點': '宜蘭',
#   '縣市': '宜蘭縣',
#   'aqi': 22.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 24.7479,
#   '經度': 121.7464},
#  {'站點': '陽明',
#   '縣市': '臺北市',
#   'aqi': 37.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 25.1827,
#   '經度': 121.5296},
#  {'站點': '花蓮',
#   '縣市': '花蓮縣',
#   'aqi': 26.0,
#   '狀態': '良好',
#   'pm25': None,
#   '緯度': 23.9713,
#   '經度': 121.5998},
#  {'站點': '臺東',
#   '縣市': '臺東縣',
#   'aqi': 25.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 22.7554,
#   '經度': 121.1505},
#  {'站點': '恆春',
#   '縣市': '屏東縣',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 21.9581,
#   '經度': 120.7889},
#  {'站點': '潮州',
#   '縣市': '屏東縣',
#   'aqi': 66.0,
#   '狀態': '普通',
#   'pm25': 19.0,
#   '緯度': 22.5231,
#   '經度': 120.5612},
#  {'站點': '屏東',
#   '縣市': '屏東縣',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 22.6731,
#   '經度': 120.488},
#  {'站點': '小港',
#   '縣市': '高雄市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 13.0,
#   '緯度': 22.5658,
#   '經度': 120.3377},
#  {'站點': '前鎮',
#   '縣市': '高雄市',
#   'aqi': 74.0,
#   '狀態': '普通',
#   'pm25': 18.0,
#   '緯度': 22.6045,
#   '經度': 120.3083},
#  {'站點': '前金',
#   '縣市': '高雄市',
#   'aqi': 78.0,
#   '狀態': '普通',
#   'pm25': 18.0,
#   '緯度': 22.6339,
#   '經度': 120.2868},
#  {'站點': '左營',
#   '縣市': '高雄市',
#   'aqi': 84.0,
#   '狀態': '普通',
#   'pm25': 26.0,
#   '緯度': 22.6749,
#   '經度': 120.2929},
#  {'站點': '楠梓',
#   '縣市': '高雄市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 17.0,
#   '緯度': 22.7337,
#   '經度': 120.3283},
#  {'站點': '林園',
#   '縣市': '高雄市',
#   'aqi': 83.0,
#   '狀態': '普通',
#   'pm25': 21.0,
#   '緯度': 22.4795,
#   '經度': 120.4117},
#  {'站點': '大寮',
#   '縣市': '高雄市',
#   'aqi': 82.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 22.5641,
#   '經度': 120.4253},
#  {'站點': '鳳山',
#   '縣市': '高雄市',
#   'aqi': 79.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 22.6281,
#   '經度': 120.3574},
#  {'站點': '仁武',
#   '縣市': '高雄市',
#   'aqi': 83.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 22.6891,
#   '經度': 120.3326},
#  {'站點': '橋頭',
#   '縣市': '高雄市',
#   'aqi': 85.0,
#   '狀態': '普通',
#   'pm25': 31.0,
#   '緯度': 22.7575,
#   '經度': 120.3057},
#  {'站點': '美濃',
#   '縣市': '高雄市',
#   'aqi': 63.0,
#   '狀態': '普通',
#   'pm25': 15.0,
#   '緯度': 22.8836,
#   '經度': 120.5305},
#  {'站點': '臺南',
#   '縣市': '臺南市',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 22.9893,
#   '經度': 120.2195},
#  {'站點': '安南',
#   '縣市': '臺南市',
#   'aqi': 78.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 23.0482,
#   '經度': 120.2175},
#  {'站點': '善化',
#   '縣市': '臺南市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 33.0,
#   '緯度': 23.1134,
#   '經度': 120.2974},
#  {'站點': '新營',
#   '縣市': '臺南市',
#   'aqi': 72.0,
#   '狀態': '普通',
#   'pm25': 30.0,
#   '緯度': 23.3056,
#   '經度': 120.3173},
#  {'站點': '嘉義',
#   '縣市': '嘉義市',
#   'aqi': 78.0,
#   '狀態': '普通',
#   'pm25': 26.0,
#   '緯度': 23.4648,
#   '經度': 120.4413},
#  {'站點': '臺西',
#   '縣市': '雲林縣',
#   'aqi': 46.0,
#   '狀態': '良好',
#   'pm25': None,
#   '緯度': 23.7022,
#   '經度': 120.1993},
#  {'站點': '朴子',
#   '縣市': '嘉義縣',
#   'aqi': 41.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 23.4654,
#   '經度': 120.2478},
#  {'站點': '新港',
#   '縣市': '嘉義縣',
#   'aqi': 72.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 23.5548,
#   '經度': 120.3455},
#  {'站點': '崙背',
#   '縣市': '雲林縣',
#   'aqi': 68.0,
#   '狀態': '普通',
#   'pm25': 21.0,
#   '緯度': 23.7575,
#   '經度': 120.3487},
#  {'站點': '斗六',
#   '縣市': '雲林縣',
#   'aqi': 91.0,
#   '狀態': '普通',
#   'pm25': None,
#   '緯度': 23.7119,
#   '經度': 120.545},
#  {'站點': '南投',
#   '縣市': '南投縣',
#   'aqi': 72.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 23.913,
#   '經度': 120.6853},
#  {'站點': '二林',
#   '縣市': '彰化縣',
#   'aqi': 74.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 23.9252,
#   '經度': 120.4097},
#  {'站點': '線西',
#   '縣市': '彰化縣',
#   'aqi': 70.0,
#   '狀態': '普通',
#   'pm25': 32.0,
#   '緯度': 24.1317,
#   '經度': 120.4691},
#  {'站點': '彰化',
#   '縣市': '彰化縣',
#   'aqi': 77.0,
#   '狀態': '普通',
#   'pm25': 31.0,
#   '緯度': 24.066,
#   '經度': 120.5415},
#  {'站點': '西屯',
#   '縣市': '臺中市',
#   'aqi': 66.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 24.1622,
#   '經度': 120.6169},
#  {'站點': '忠明',
#   '縣市': '臺中市',
#   'aqi': 65.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 24.152,
#   '經度': 120.6411},
#  {'站點': '大里',
#   '縣市': '臺中市',
#   'aqi': 71.0,
#   '狀態': '普通',
#   'pm25': 20.0,
#   '緯度': 24.0996,
#   '經度': 120.6784},
#  {'站點': '沙鹿',
#   '縣市': '臺中市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 26.0,
#   '緯度': 24.2256,
#   '經度': 120.5688},
#  {'站點': '豐原',
#   '縣市': '臺中市',
#   'aqi': 63.0,
#   '狀態': '普通',
#   'pm25': 26.0,
#   '緯度': 24.257,
#   '經度': 120.7425},
#  {'站點': '三義',
#   '縣市': '苗栗縣',
#   'aqi': 52.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 24.3825,
#   '經度': 120.7596},
#  {'站點': '苗栗',
#   '縣市': '苗栗縣',
#   'aqi': 50.0,
#   '狀態': '良好',
#   'pm25': 23.0,
#   '緯度': 24.565,
#   '經度': 120.8201},
#  {'站點': '頭份',
#   '縣市': '苗栗縣',
#   'aqi': 38.0,
#   '狀態': '良好',
#   'pm25': 17.0,
#   '緯度': 24.6969,
#   '經度': 120.8987},
#  {'站點': '新竹',
#   '縣市': '新竹市',
#   'aqi': 38.0,
#   '狀態': '良好',
#   'pm25': 17.0,
#   '緯度': 24.8056,
#   '經度': 120.9724},
#  {'站點': '竹東',
#   '縣市': '新竹縣',
#   'aqi': 19.0,
#   '狀態': '良好',
#   'pm25': None,
#   '緯度': 24.7409,
#   '經度': 121.089},
#  {'站點': '湖口',
#   '縣市': '新竹縣',
#   'aqi': 42.0,
#   '狀態': '良好',
#   'pm25': 17.0,
#   '緯度': 24.9001,
#   '經度': 121.0389},
#  {'站點': '龍潭',
#   '縣市': '桃園市',
#   'aqi': 34.0,
#   '狀態': '良好',
#   'pm25': 15.0,
#   '緯度': 24.864,
#   '經度': 121.2165},
#  {'站點': '平鎮',
#   '縣市': '桃園市',
#   'aqi': 29.0,
#   '狀態': '良好',
#   'pm25': 17.0,
#   '緯度': 24.9528,
#   '經度': 121.204},
#  {'站點': '觀音',
#   '縣市': '桃園市',
#   'aqi': 56.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 25.0356,
#   '經度': 121.0828},
#  {'站點': '大園',
#   '縣市': '桃園市',
#   'aqi': 38.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 25.061,
#   '經度': 121.2025},
#  {'站點': '桃園',
#   '縣市': '桃園市',
#   'aqi': 29.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 24.9947,
#   '經度': 121.305},
#  {'站點': '大同',
#   '縣市': '臺北市',
#   'aqi': 52.0,
#   '狀態': '普通',
#   'pm25': 13.0,
#   '緯度': 25.0633,
#   '經度': 121.5134},
#  {'站點': '松山',
#   '縣市': '臺北市',
#   'aqi': 29.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 25.05,
#   '經度': 121.5786},
#  {'站點': '古亭',
#   '縣市': '臺北市',
#   'aqi': 32.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 25.0206,
#   '經度': 121.5296},
#  {'站點': '萬華',
#   '縣市': '臺北市',
#   'aqi': 26.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 25.0465,
#   '經度': 121.508},
#  {'站點': '中山',
#   '縣市': '臺北市',
#   'aqi': 26.0,
#   '狀態': '良好',
#   'pm25': 14.0,
#   '緯度': 25.0624,
#   '經度': 121.5265},
#  {'站點': '士林',
#   '縣市': '臺北市',
#   'aqi': 35.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 25.1033,
#   '經度': 121.5167},
#  {'站點': '淡水',
#   '縣市': '新北市',
#   'aqi': 36.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 25.1645,
#   '經度': 121.4492},
#  {'站點': '林口',
#   '縣市': '新北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 25.078,
#   '經度': 121.3655},
#  {'站點': '菜寮',
#   '縣市': '新北市',
#   'aqi': 32.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 25.069,
#   '經度': 121.481},
#  {'站點': '新莊',
#   '縣市': '新北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 25.038,
#   '經度': 121.4325},
#  {'站點': '板橋',
#   '縣市': '新北市',
#   'aqi': 32.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 25.013,
#   '經度': 121.4587},
#  {'站點': '土城',
#   '縣市': '新北市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 24.9825,
#   '經度': 121.4519},
#  {'站點': '新店',
#   '縣市': '新北市',
#   'aqi': 34.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 24.9772,
#   '經度': 121.5378},
#  {'站點': '萬里',
#   '縣市': '新北市',
#   'aqi': 30.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 25.1797,
#   '經度': 121.6899},
#  {'站點': '汐止',
#   '縣市': '新北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 13.0,
#   '緯度': 25.0662,
#   '經度': 121.6408},
#  {'站點': '基隆',
#   '縣市': '基隆市',
#   'aqi': 26.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 25.1292,
#   '經度': 121.7601},
#  {'站點': '屏東(枋山)',
#   '縣市': '屏東縣',
#   'aqi': 49.0,
#   '狀態': '良好',
#   'pm25': 22.0,
#   '緯度': 22.2609,
#   '經度': 120.6515},
#  {'站點': '新北(樹林)',
#   '縣市': '新北市',
#   'aqi': 48.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 24.949,
#   '經度': 121.3835},
#  {'站點': '屏東（琉球）',
#   '縣市': '屏東縣',
#   'aqi': 79.0,
#   '狀態': '普通',
#   'pm25': None,
#   '緯度': 22.3522,
#   '經度': 120.3772},
#  {'站點': '臺南（麻豆）',
#   '縣市': '臺南市',
#   'aqi': 58.0,
#   '狀態': '普通',
#   'pm25': 16.0,
#   '緯度': 23.179,
#   '經度': 120.2458},
#  {'站點': '高雄（湖內）',
#   '縣市': '高雄市',
#   'aqi': 80.0,
#   '狀態': '普通',
#   'pm25': 31.0,
#   '緯度': 22.8799,
#   '經度': 120.2454},
#  {'站點': '彰化（員林）',
#   '縣市': '彰化縣',
#   'aqi': 75.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 23.9612,
#   '經度': 120.5637},
#  {'站點': '大城',
#   '縣市': '彰化縣',
#   'aqi': 37.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 23.8549,
#   '經度': 120.2696},
#  {'站點': '富貴角',
#   '縣市': '新北市',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 25.2968,
#   '經度': 121.5366},
#  {'站點': '麥寮',
#   '縣市': '雲林縣',
#   'aqi': 51.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 23.7535,
#   '經度': 120.2518},
#  {'站點': '關山',
#   '縣市': '臺東縣',
#   'aqi': 20.0,
#   '狀態': '良好',
#   'pm25': 3.0,
#   '緯度': 23.0451,
#   '經度': 121.1619},
#  {'站點': '馬公',
#   '縣市': '澎湖縣',
#   'aqi': 38.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 23.569,
#   '經度': 119.5662},
#  {'站點': '金門',
#   '縣市': '金門縣',
#   'aqi': 27.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 24.4321,
#   '經度': 118.3123},
#  {'站點': '馬祖',
#   '縣市': '連江縣',
#   'aqi': 34.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 26.1537,
#   '經度': 119.9527},
#  {'站點': '埔里',
#   '縣市': '南投縣',
#   'aqi': 66.0,
#   '狀態': '普通',
#   'pm25': 15.0,
#   '緯度': 23.9688,
#   '經度': 120.9679},
#  {'站點': '復興',
# ...
#   '縣市': '金門縣',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 24.4321,
#   '經度': 118.3123},
#  {'站點': '馬祖',
#   '縣市': '連江縣',
#   'aqi': 37.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 26.1537,
#   '經度': 119.9527},
#  {'站點': '埔里',
#   '縣市': '南投縣',
#   'aqi': 67.0,
#   '狀態': '普通',
#   'pm25': 20.0,
#   '緯度': 23.9688,
#   '經度': 120.9679},
#  {'站點': '復興',
#   '縣市': '高雄市',
#   'aqi': 96.0,
#   '狀態': '普通',
#   'pm25': 41.0,
#   '緯度': 22.6087,
#   '經度': 120.312},
#  {'站點': '永和',
#   '縣市': '新北市',
#   'aqi': 47.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 25.017,
#   '經度': 121.5163},
#  {'站點': '竹山',
#   '縣市': '南投縣',
#   'aqi': 81.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 23.7564,
#   '經度': 120.6773},
#  {'站點': '中壢',
#   '縣市': '桃園市',
#   'aqi': 53.0,
#   '狀態': '普通',
#   'pm25': 10.0,
#   '緯度': 24.9533,
#   '經度': 121.2217},
#  {'站點': '三重',
#   '縣市': '新北市',
#   'aqi': 56.0,
#   '狀態': '普通',
#   'pm25': 12.0,
#   '緯度': 25.0726,
#   '經度': 121.4938},
#  {'站點': '冬山',
#   '縣市': '宜蘭縣',
#   'aqi': 27.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 24.6322,
#   '經度': 121.7929},
#  {'站點': '宜蘭',
#   '縣市': '宜蘭縣',
#   'aqi': 23.0,
#   '狀態': '良好',
#   'pm25': 0.0,
#   '緯度': 24.7479,
#   '經度': 121.7464},
#  {'站點': '陽明',
#   '縣市': '臺北市',
#   'aqi': 38.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 25.1827,
#   '經度': 121.5296},
#  {'站點': '花蓮',
#   '縣市': '花蓮縣',
#   'aqi': 29.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 23.9713,
#   '經度': 121.5998},
#  {'站點': '臺東',
#   '縣市': '臺東縣',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 22.7554,
#   '經度': 121.1505},
#  {'站點': '恆春',
#   '縣市': '屏東縣',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 21.9581,
#   '經度': 120.7889},
#  {'站點': '潮州',
#   '縣市': '屏東縣',
#   'aqi': 72.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 22.5231,
#   '經度': 120.5612},
#  {'站點': '屏東',
#   '縣市': '屏東縣',
#   'aqi': 78.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 22.6731,
#   '經度': 120.488},
#  {'站點': '小港',
#   '縣市': '高雄市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 35.0,
#   '緯度': 22.5658,
#   '經度': 120.3377},
#  {'站點': '前鎮',
#   '縣市': '高雄市',
#   'aqi': 85.0,
#   '狀態': '普通',
#   'pm25': 36.0,
#   '緯度': 22.6045,
#   '經度': 120.3083},
#  {'站點': '前金',
#   '縣市': '高雄市',
#   'aqi': 81.0,
#   '狀態': '普通',
#   'pm25': 34.0,
#   '緯度': 22.6339,
#   '經度': 120.2868},
#  {'站點': '左營',
#   '縣市': '高雄市',
#   'aqi': 79.0,
#   '狀態': '普通',
#   'pm25': 29.0,
#   '緯度': 22.6749,
#   '經度': 120.2929},
#  {'站點': '楠梓',
#   '縣市': '高雄市',
#   'aqi': 79.0,
#   '狀態': '普通',
#   'pm25': 37.0,
#   '緯度': 22.7337,
#   '經度': 120.3283},
#  {'站點': '林園',
#   '縣市': '高雄市',
#   'aqi': 81.0,
#   '狀態': '普通',
#   'pm25': 35.0,
#   '緯度': 22.4795,
#   '經度': 120.4117},
#  {'站點': '大寮',
#   '縣市': '高雄市',
#   'aqi': 79.0,
#   '狀態': '普通',
#   'pm25': 32.0,
#   '緯度': 22.5641,
#   '經度': 120.4253},
#  {'站點': '鳳山',
#   '縣市': '高雄市',
#   'aqi': 87.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 22.6281,
#   '經度': 120.3574},
#  {'站點': '仁武',
#   '縣市': '高雄市',
#   'aqi': 83.0,
#   '狀態': '普通',
#   'pm25': 33.0,
#   '緯度': 22.6891,
#   '經度': 120.3326},
#  {'站點': '橋頭',
#   '縣市': '高雄市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 33.0,
#   '緯度': 22.7575,
#   '經度': 120.3057},
#  {'站點': '美濃',
#   '縣市': '高雄市',
#   'aqi': 62.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 22.8836,
#   '經度': 120.5305},
#  {'站點': '臺南',
#   '縣市': '臺南市',
#   'aqi': 63.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 22.9893,
#   '經度': 120.2195},
#  {'站點': '安南',
#   '縣市': '臺南市',
#   'aqi': 61.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 23.0482,
#   '經度': 120.2175},
#  {'站點': '善化',
#   '縣市': '臺南市',
#   'aqi': 57.0,
#   '狀態': '普通',
#   'pm25': 21.0,
#   '緯度': 23.1134,
#   '經度': 120.2974},
#  {'站點': '新營',
#   '縣市': '臺南市',
#   'aqi': 60.0,
#   '狀態': '普通',
#   'pm25': 19.0,
#   '緯度': 23.3056,
#   '經度': 120.3173},
#  {'站點': '嘉義',
#   '縣市': '嘉義市',
#   'aqi': 69.0,
#   '狀態': '普通',
#   'pm25': 28.0,
#   '緯度': 23.4648,
#   '經度': 120.4413},
#  {'站點': '臺西',
#   '縣市': '雲林縣',
#   'aqi': 38.0,
#   '狀態': '良好',
#   'pm25': 16.0,
#   '緯度': 23.7022,
#   '經度': 120.1993},
#  {'站點': '朴子',
#   '縣市': '嘉義縣',
#   'aqi': 37.0,
#   '狀態': '良好',
#   'pm25': 19.0,
#   '緯度': 23.4654,
#   '經度': 120.2478},
#  {'站點': '新港',
#   '縣市': '嘉義縣',
#   'aqi': 57.0,
#   '狀態': '普通',
#   'pm25': 26.0,
#   '緯度': 23.5548,
#   '經度': 120.3455},
#  {'站點': '崙背',
#   '縣市': '雲林縣',
#   'aqi': 56.0,
#   '狀態': '普通',
#   'pm25': 26.0,
#   '緯度': 23.7575,
#   '經度': 120.3487},
#  {'站點': '斗六',
#   '縣市': '雲林縣',
#   'aqi': 81.0,
#   '狀態': '普通',
#   'pm25': 30.0,
#   '緯度': 23.7119,
#   '經度': 120.545},
#  {'站點': '南投',
#   '縣市': '南投縣',
#   'aqi': 69.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 23.913,
#   '經度': 120.6853},
#  {'站點': '二林',
#   '縣市': '彰化縣',
#   'aqi': 60.0,
#   '狀態': '普通',
#   'pm25': 28.0,
#   '緯度': 23.9252,
#   '經度': 120.4097},
#  {'站點': '線西',
#   '縣市': '彰化縣',
#   'aqi': 49.0,
#   '狀態': '良好',
#   'pm25': 26.0,
#   '緯度': 24.1317,
#   '經度': 120.4691},
#  {'站點': '彰化',
#   '縣市': '彰化縣',
#   'aqi': 62.0,
#   '狀態': '普通',
#   'pm25': 26.0,
#   '緯度': 24.066,
#   '經度': 120.5415},
#  {'站點': '西屯',
#   '縣市': '臺中市',
#   'aqi': 61.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 24.1622,
#   '經度': 120.6169},
#  {'站點': '忠明',
#   '縣市': '臺中市',
#   'aqi': 57.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 24.152,
#   '經度': 120.6411},
#  {'站點': '大里',
#   '縣市': '臺中市',
#   'aqi': 63.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 24.0996,
#   '經度': 120.6784},
#  {'站點': '沙鹿',
#   '縣市': '臺中市',
#   'aqi': 55.0,
#   '狀態': '普通',
#   'pm25': 31.0,
#   '緯度': 24.2256,
#   '經度': 120.5688},
#  {'站點': '豐原',
#   '縣市': '臺中市',
#   'aqi': 46.0,
#   '狀態': '良好',
#   'pm25': 14.0,
#   '緯度': 24.257,
#   '經度': 120.7425},
#  {'站點': '三義',
#   '縣市': '苗栗縣',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': 12.0,
#   '緯度': 24.3825,
#   '經度': 120.7596},
#  {'站點': '苗栗',
#   '縣市': '苗栗縣',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 16.0,
#   '緯度': 24.565,
#   '經度': 120.8201},
#  {'站點': '頭份',
#   '縣市': '苗栗縣',
#   'aqi': 23.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 24.6969,
#   '經度': 120.8987},
#  {'站點': '新竹',
#   '縣市': '新竹市',
#   'aqi': 32.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 24.8056,
#   '經度': 120.9724},
#  {'站點': '竹東',
#   '縣市': '新竹縣',
#   'aqi': 15.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 24.7409,
#   '經度': 121.089},
#  {'站點': '湖口',
#   '縣市': '新竹縣',
#   'aqi': 27.0,
#   '狀態': '良好',
#   'pm25': 21.0,
#   '緯度': 24.9001,
#   '經度': 121.0389},
#  {'站點': '龍潭',
#   '縣市': '桃園市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 14.0,
#   '緯度': 24.864,
#   '經度': 121.2165},
#  {'站點': '平鎮',
#   '縣市': '桃園市',
#   'aqi': 52.0,
#   '狀態': '普通',
#   'pm25': 10.0,
#   '緯度': 24.9528,
#   '經度': 121.204},
#  {'站點': '觀音',
#   '縣市': '桃園市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 21.0,
#   '緯度': 25.0356,
#   '經度': 121.0828},
#  {'站點': '大園',
#   '縣市': '桃園市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 25.061,
#   '經度': 121.2025},
#  {'站點': '桃園',
#   '縣市': '桃園市',
#   'aqi': 43.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 24.9947,
#   '經度': 121.305},
#  {'站點': '大同',
#   '縣市': '臺北市',
#   'aqi': 52.0,
#   '狀態': '普通',
#   'pm25': 13.0,
#   '緯度': 25.0633,
#   '經度': 121.5134},
#  {'站點': '松山',
#   '縣市': '臺北市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 25.05,
#   '經度': 121.5786},
#  {'站點': '古亭',
#   '縣市': '臺北市',
#   'aqi': 32.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 25.0206,
#   '經度': 121.5296},
#  {'站點': '萬華',
#   '縣市': '臺北市',
#   'aqi': 38.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 25.0465,
#   '經度': 121.508},
#  {'站點': '中山',
#   '縣市': '臺北市',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 25.0624,
#   '經度': 121.5265},
#  {'站點': '士林',
#   '縣市': '臺北市',
#   'aqi': 37.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 25.1033,
#   '經度': 121.5167},
#  {'站點': '淡水',
#   '縣市': '新北市',
#   'aqi': 37.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 25.1645,
#   '經度': 121.4492},
#  {'站點': '林口',
#   '縣市': '新北市',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 25.078,
#   '經度': 121.3655},
#  {'站點': '菜寮',
#   '縣市': '新北市',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 25.069,
#   '經度': 121.481},
#  {'站點': '新莊',
#   '縣市': '新北市',
#   'aqi': 33.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 25.038,
#   '經度': 121.4325},
#  {'站點': '板橋',
#   '縣市': '新北市',
#   'aqi': 34.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 25.013,
#   '經度': 121.4587},
#  {'站點': '土城',
#   '縣市': '新北市',
#   'aqi': 52.0,
#   '狀態': '普通',
#   'pm25': 15.0,
#   '緯度': 24.9825,
#   '經度': 121.4519},
#  {'站點': '新店',
#   '縣市': '新北市',
#   'aqi': 34.0,
#   '狀態': '良好',
#   'pm25': 13.0,
#   '緯度': 24.9772,
#   '經度': 121.5378},
#  {'站點': '萬里',
#   '縣市': '新北市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 25.1797,
#   '經度': 121.6899},
#  {'站點': '汐止',
#   '縣市': '新北市',
#   'aqi': 52.0,
#   '狀態': '普通',
#   'pm25': 18.0,
#   '緯度': 25.0662,
#   '經度': 121.6408},
#  {'站點': '基隆',
#   '縣市': '基隆市',
#   'aqi': 25.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 25.1292,
#   '經度': 121.7601},
#  {'站點': '屏東(枋山)',
#   '縣市': '屏東縣',
#   'aqi': 39.0,
#   '狀態': '良好',
#   'pm25': 17.0,
#   '緯度': 22.2609,
#   '經度': 120.6515},
#  {'站點': '新北(樹林)',
#   '縣市': '新北市',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 24.949,
#   '經度': 121.3835},
#  {'站點': '屏東（琉球）',
#   '縣市': '屏東縣',
#   'aqi': 63.0,
#   '狀態': '普通',
#   'pm25': 35.0,
#   '緯度': 22.3522,
#   '經度': 120.3772},
#  {'站點': '臺南（麻豆）',
#   '縣市': '臺南市',
#   'aqi': 47.0,
#   '狀態': '良好',
#   'pm25': 16.0,
#   '緯度': 23.179,
#   '經度': 120.2458},
#  {'站點': '高雄（湖內）',
#   '縣市': '高雄市',
#   'aqi': 63.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 22.8799,
#   '經度': 120.2454},
#  {'站點': '彰化（員林）',
#   '縣市': '彰化縣',
#   'aqi': 65.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 23.9612,
#   '經度': 120.5637},
#  {'站點': '大城',
#   '縣市': '彰化縣',
#   'aqi': 39.0,
#   '狀態': '良好',
#   'pm25': 17.0,
#   '緯度': 23.8549,
#   '經度': 120.2696},
#  {'站點': '富貴角',
#   '縣市': '新北市',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 25.2968,
#   '經度': 121.5366},
#  {'站點': '麥寮',
#   '縣市': '雲林縣',
#   'aqi': 42.0,
#   '狀態': '良好',
#   'pm25': 19.0,
#   '緯度': 23.7535,
#   '經度': 120.2518},
#  {'站點': '關山',
#   '縣市': '臺東縣',
#   'aqi': 21.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 23.0451,
#   '經度': 121.1619},
#  {'站點': '馬公',
#   '縣市': '澎湖縣',
#   'aqi': 39.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 23.569,
#   '經度': 119.5662},
#  {'站點': '金門',
#   '縣市': '金門縣',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 24.4321,
#   '經度': 118.3123},
#  {'站點': '馬祖',
#   '縣市': '連江縣',
#   'aqi': 37.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 26.1537,
#   '經度': 119.9527},
#  {'站點': '埔里',
#   '縣市': '南投縣',
#   'aqi': 67.0,
#   '狀態': '普通',
#   'pm25': 20.0,
#   '緯度': 23.9688,
#   '經度': 120.9679},
#  {'站點': '復興',
#   '縣市': '高雄市',
#   'aqi': 96.0,
#   '狀態': '普通',
#   'pm25': 41.0,
#   '緯度': 22.6087,
#   '經度': 120.312},
#  {'站點': '永和',
#   '縣市': '新北市',
#   'aqi': 47.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 25.017,
#   '經度': 121.5163},
#  {'站點': '竹山',
#   '縣市': '南投縣',
#   'aqi': 81.0,
#   '狀態': '普通',
#   'pm25': 25.0,
#   '緯度': 23.7564,
#   '經度': 120.6773},
#  {'站點': '中壢',
#   '縣市': '桃園市',
#   'aqi': 53.0,
#   '狀態': '普通',
#   'pm25': 10.0,
#   '緯度': 24.9533,
#   '經度': 121.2217},
#  {'站點': '三重',
#   '縣市': '新北市',
#   'aqi': 56.0,
#   '狀態': '普通',
#   'pm25': 12.0,
#   '緯度': 25.0726,
#   '經度': 121.4938},
#  {'站點': '冬山',
#   '縣市': '宜蘭縣',
#   'aqi': 27.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 24.6322,
#   '經度': 121.7929},
#  {'站點': '宜蘭',
#   '縣市': '宜蘭縣',
#   'aqi': 23.0,
#   '狀態': '良好',
#   'pm25': 0.0,
#   '緯度': 24.7479,
#   '經度': 121.7464},
#  {'站點': '陽明',
#   '縣市': '臺北市',
#   'aqi': 38.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 25.1827,
#   '經度': 121.5296},
#  {'站點': '花蓮',
#   '縣市': '花蓮縣',
#   'aqi': 29.0,
#   '狀態': '良好',
#   'pm25': 10.0,
#   '緯度': 23.9713,
#   '經度': 121.5998},
#  {'站點': '臺東',
#   '縣市': '臺東縣',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 22.7554,
#   '經度': 121.1505},
#  {'站點': '恆春',
#   '縣市': '屏東縣',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 21.9581,
#   '經度': 120.7889},
#  {'站點': '潮州',
#   '縣市': '屏東縣',
#   'aqi': 72.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 22.5231,
#   '經度': 120.5612},
#  {'站點': '屏東',
#   '縣市': '屏東縣',
#   'aqi': 78.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 22.6731,
#   '經度': 120.488},
#  {'站點': '小港',
#   '縣市': '高雄市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 35.0,
#   '緯度': 22.5658,
#   '經度': 120.3377},
#  {'站點': '前鎮',
#   '縣市': '高雄市',
#   'aqi': 85.0,
#   '狀態': '普通',
#   'pm25': 36.0,
#   '緯度': 22.6045,
#   '經度': 120.3083},
#  {'站點': '前金',
#   '縣市': '高雄市',
#   'aqi': 81.0,
#   '狀態': '普通',
#   'pm25': 34.0,
#   '緯度': 22.6339,
#   '經度': 120.2868},
#  {'站點': '左營',
#   '縣市': '高雄市',
#   'aqi': 79.0,
#   '狀態': '普通',
#   'pm25': 29.0,
#   '緯度': 22.6749,
#   '經度': 120.2929},
#  {'站點': '楠梓',
#   '縣市': '高雄市',
#   'aqi': 79.0,
#   '狀態': '普通',
#   'pm25': 37.0,
#   '緯度': 22.7337,
#   '經度': 120.3283},
#  {'站點': '林園',
#   '縣市': '高雄市',
#   'aqi': 81.0,
#   '狀態': '普通',
#   'pm25': 35.0,
#   '緯度': 22.4795,
#   '經度': 120.4117},
#  {'站點': '大寮',
#   '縣市': '高雄市',
#   'aqi': 79.0,
#   '狀態': '普通',
#   'pm25': 32.0,
#   '緯度': 22.5641,
#   '經度': 120.4253},
#  {'站點': '鳳山',
#   '縣市': '高雄市',
#   'aqi': 87.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 22.6281,
#   '經度': 120.3574},
#  {'站點': '仁武',
#   '縣市': '高雄市',
#   'aqi': 83.0,
#   '狀態': '普通',
#   'pm25': 33.0,
#   '緯度': 22.6891,
#   '經度': 120.3326},
#  {'站點': '橋頭',
#   '縣市': '高雄市',
#   'aqi': 76.0,
#   '狀態': '普通',
#   'pm25': 33.0,
#   '緯度': 22.7575,
#   '經度': 120.3057},
#  {'站點': '美濃',
#   '縣市': '高雄市',
#   'aqi': 62.0,
#   '狀態': '普通',
#   'pm25': 22.0,
#   '緯度': 22.8836,
#   '經度': 120.5305},
#  {'站點': '臺南',
#   '縣市': '臺南市',
#   'aqi': 63.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 22.9893,
#   '經度': 120.2195},
#  {'站點': '安南',
#   '縣市': '臺南市',
#   'aqi': 61.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 23.0482,
#   '經度': 120.2175},
#  {'站點': '善化',
#   '縣市': '臺南市',
#   'aqi': 57.0,
#   '狀態': '普通',
#   'pm25': 21.0,
#   '緯度': 23.1134,
#   '經度': 120.2974},
#  {'站點': '新營',
#   '縣市': '臺南市',
#   'aqi': 60.0,
#   '狀態': '普通',
#   'pm25': 19.0,
#   '緯度': 23.3056,
#   '經度': 120.3173},
#  {'站點': '嘉義',
#   '縣市': '嘉義市',
#   'aqi': 69.0,
#   '狀態': '普通',
#   'pm25': 28.0,
#   '緯度': 23.4648,
#   '經度': 120.4413},
#  {'站點': '臺西',
#   '縣市': '雲林縣',
#   'aqi': 38.0,
#   '狀態': '良好',
#   'pm25': 16.0,
#   '緯度': 23.7022,
#   '經度': 120.1993},
#  {'站點': '朴子',
#   '縣市': '嘉義縣',
#   'aqi': 37.0,
#   '狀態': '良好',
#   'pm25': 19.0,
#   '緯度': 23.4654,
#   '經度': 120.2478},
#  {'站點': '新港',
#   '縣市': '嘉義縣',
#   'aqi': 57.0,
#   '狀態': '普通',
#   'pm25': 26.0,
#   '緯度': 23.5548,
#   '經度': 120.3455},
#  {'站點': '崙背',
#   '縣市': '雲林縣',
#   'aqi': 56.0,
#   '狀態': '普通',
#   'pm25': 26.0,
#   '緯度': 23.7575,
#   '經度': 120.3487},
#  {'站點': '斗六',
#   '縣市': '雲林縣',
#   'aqi': 81.0,
#   '狀態': '普通',
#   'pm25': 30.0,
#   '緯度': 23.7119,
#   '經度': 120.545},
#  {'站點': '南投',
#   '縣市': '南投縣',
#   'aqi': 69.0,
#   '狀態': '普通',
#   'pm25': 27.0,
#   '緯度': 23.913,
#   '經度': 120.6853},
#  {'站點': '二林',
#   '縣市': '彰化縣',
#   'aqi': 60.0,
#   '狀態': '普通',
#   'pm25': 28.0,
#   '緯度': 23.9252,
#   '經度': 120.4097},
#  {'站點': '線西',
#   '縣市': '彰化縣',
#   'aqi': 49.0,
#   '狀態': '良好',
#   'pm25': 26.0,
#   '緯度': 24.1317,
#   '經度': 120.4691},
#  {'站點': '彰化',
#   '縣市': '彰化縣',
#   'aqi': 62.0,
#   '狀態': '普通',
#   'pm25': 26.0,
#   '緯度': 24.066,
#   '經度': 120.5415},
#  {'站點': '西屯',
#   '縣市': '臺中市',
#   'aqi': 61.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 24.1622,
#   '經度': 120.6169},
#  {'站點': '忠明',
#   '縣市': '臺中市',
#   'aqi': 57.0,
#   '狀態': '普通',
#   'pm25': 24.0,
#   '緯度': 24.152,
#   '經度': 120.6411},
#  {'站點': '大里',
#   '縣市': '臺中市',
#   'aqi': 63.0,
#   '狀態': '普通',
#   'pm25': 23.0,
#   '緯度': 24.0996,
#   '經度': 120.6784},
#  {'站點': '沙鹿',
#   '縣市': '臺中市',
#   'aqi': 55.0,
#   '狀態': '普通',
#   'pm25': 31.0,
#   '緯度': 24.2256,
#   '經度': 120.5688},
#  {'站點': '豐原',
#   '縣市': '臺中市',
#   'aqi': 46.0,
#   '狀態': '良好',
#   'pm25': 14.0,
#   '緯度': 24.257,
#   '經度': 120.7425},
#  {'站點': '三義',
#   '縣市': '苗栗縣',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': 12.0,
#   '緯度': 24.3825,
#   '經度': 120.7596},
#  {'站點': '苗栗',
#   '縣市': '苗栗縣',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 16.0,
#   '緯度': 24.565,
#   '經度': 120.8201},
#  {'站點': '頭份',
#   '縣市': '苗栗縣',
#   'aqi': 23.0,
#   '狀態': '良好',
#   'pm25': 6.0,
#   '緯度': 24.6969,
#   '經度': 120.8987},
#  {'站點': '新竹',
#   '縣市': '新竹市',
#   'aqi': 32.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 24.8056,
#   '經度': 120.9724},
#  {'站點': '竹東',
#   '縣市': '新竹縣',
#   'aqi': 15.0,
#   '狀態': '良好',
#   'pm25': 4.0,
#   '緯度': 24.7409,
#   '經度': 121.089},
#  {'站點': '湖口',
#   '縣市': '新竹縣',
#   'aqi': 27.0,
#   '狀態': '良好',
#   'pm25': 21.0,
#   '緯度': 24.9001,
#   '經度': 121.0389},
#  {'站點': '龍潭',
#   '縣市': '桃園市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 14.0,
#   '緯度': 24.864,
#   '經度': 121.2165},
#  {'站點': '平鎮',
#   '縣市': '桃園市',
#   'aqi': 52.0,
#   '狀態': '普通',
#   'pm25': 10.0,
#   '緯度': 24.9528,
#   '經度': 121.204},
#  {'站點': '觀音',
#   '縣市': '桃園市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 21.0,
#   '緯度': 25.0356,
#   '經度': 121.0828},
#  {'站點': '大園',
#   '縣市': '桃園市',
#   'aqi': 31.0,
#   '狀態': '良好',
#   'pm25': 7.0,
#   '緯度': 25.061,
#   '經度': 121.2025},
#  {'站點': '桃園',
#   '縣市': '桃園市',
#   'aqi': 43.0,
#   '狀態': '良好',
#   'pm25': 8.0,
#   '緯度': 24.9947,
#   '經度': 121.305},
#  {'站點': '大同',
#   '縣市': '臺北市',
#   'aqi': 52.0,
#   '狀態': '普通',
#   'pm25': 13.0,
#   '緯度': 25.0633,
#   '經度': 121.5134},
#  {'站點': '松山',
#   '縣市': '臺北市',
#   'aqi': 28.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 25.05,
#   '經度': 121.5786},
#  {'站點': '古亭',
#   '縣市': '臺北市',
#   'aqi': 32.0,
#   '狀態': '良好',
#   'pm25': 11.0,
#   '緯度': 25.0206,
#   '經度': 121.5296},
#  {'站點': '萬華',
#   '縣市': '臺北市',
#   'aqi': 38.0,
#   '狀態': '良好',
#   'pm25': 9.0,
#   '緯度': 25.0465,
#   '經度': 121.508},
#  {'站點': '中山',
#   '縣市': '臺北市',
#   'aqi': 40.0,
#   '狀態': '良好',
#   'pm25': 5.0,
#   '緯度': 25.0624,
#   '經度': 121.5265}]
