# %%
import pandas as pd

df = pd.read_csv('C:\\Users\\user\\Documents\\GitHub\\202409_TVDI_Project_Stock_analysis\\NewTable_202412100949.csv')
df
# Out:
#       id        Date    Open    High     Low    Adj Close    Volume   Close  \
# 0    NaN  2020-01-02   332.5   339.0   332.5   306.430145  31754120   339.0
# 1    NaN  2020-01-03   344.0   345.0   335.5   306.882202  41811268   339.5
# 2    NaN  2020-01-06   333.0   334.5   332.0   300.102692  45343057   332.0
# 3    NaN  2020-01-07   332.5   333.0   326.5   297.842957  50879181   329.5
# 4    NaN  2020-01-08   325.0   333.0   325.0   297.842957  37567748   329.5
# ...   ..         ...     ...     ...     ...          ...       ...     ...
# 2413 NaN  2024-12-02  1020.0  1040.0  1015.0  1035.000000  31168404  1035.0
# 2414 NaN  2024-12-03  1060.0  1065.0  1055.0  1055.000000  43414538  1055.0
# 2415 NaN  2024-12-04  1065.0  1070.0  1055.0  1070.000000  33466290  1070.0
# 2416 NaN  2024-12-05  1070.0  1080.0  1070.0  1075.000000  31425359  1075.0
# 2417 NaN  2024-12-06  1075.0  1080.0  1060.0  1065.000000  30765288  1065.0
#
#       Tickers
# 0     2330.TW
# 1     2330.TW
# ...

# %%
df['Close']
# Out:
# 0        339.0
# 1        339.5
# 2        332.0
# 3        329.5
# 4        329.5
#          ...
# 2413    1035.0
# 2414    1055.0
# 2415    1070.0
# 2416    1075.0
# 2417    1065.0
# Name: Close, Length: 2418, dtype: float64

# %%
df.Close
# Out:
# 0        339.0
# 1        339.5
# 2        332.0
# 3        329.5
# 4        329.5
#          ...
# 2413    1035.0
# 2414    1055.0
# 2415    1070.0
# 2416    1075.0
# 2417    1065.0
# Name: Close, Length: 2418, dtype: float64

# %%
df.Date
# Out:
# 0       2020-01-02
# 1       2020-01-03
# 2       2020-01-06
# 3       2020-01-07
# 4       2020-01-08
#            ...
# 2413    2024-12-02
# 2414    2024-12-03
# 2415    2024-12-04
# 2416    2024-12-05
# 2417    2024-12-06
# Name: Date, Length: 2418, dtype: object

# %%
df.to_dict(orient='records')
# Out:
# [{'id': nan,
#   'Date': '2020-01-02',
#   'Open': 332.5,
#   'High': 339.0,
#   'Low': 332.5,
#   'Adj Close': 306.4301452636719,
#   'Volume': 31754120,
#   'Close': 339.0,
#   'Tickers': '2330.TW'},
#  {'id': nan,
#   'Date': '2020-01-03',
#   'Open': 344.0,
#   'High': 345.0,
#   'Low': 335.5,
#   'Adj Close': 306.8822021484375,
#   'Volume': 41811268,
#   'Close': 339.5,
#   'Tickers': '2330.TW'},
#  {'id': nan,
#   'Date': '2020-01-06',
#   'Open': 333.0,
#   'High': 334.5,
#   'Low': 332.0,
#   'Adj Close': 300.1026916503906,
#   'Volume': 45343057,
#   'Close': 332.0,
#   'Tickers': '2330.TW'},
#  {'id': nan,
#   'Date': '2020-01-07',
#   'Open': 332.5,
#   'High': 333.0,
#   'Low': 326.5,
#   'Adj Close': 297.84295654296875,
#   'Volume': 50879181,
#   'Close': 329.5,
#   'Tickers': '2330.TW'},
#  {'id': nan,
#   'Date': '2020-01-08',
#   'Open': 325.0,
#   'High': 333.0,
#   'Low': 325.0,
#   'Adj Close': 297.84295654296875,
#   'Volume': 37567748,
#   'Close': 329.5,
# ...
